# %% [markdown]
# Import Libraries and Packages

# %%
import os
import shutil
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import opendatasets as od
import tensorflow as tf
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %% [markdown]
# Data Extraction

# %%
# Download the dataset
dataset_url = 'https://www.kaggle.com/datasets/msambare/fer2013'
od.download(dataset_url)

# Define dataset paths
train_path = "fer2013/train"
val_path = "fer2013/test"
# Out:
# Skipping, found downloaded files in ".\fer2013" (use force=True to force download)

# %% [markdown]
# Data Pre-Processing

# %%
# Initialize data generators with data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
val_datagen = ImageDataGenerator(rescale=1./255)

# Load training and validation data
batch_size = 64
target_size = (48, 48)
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=target_size,
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical',
    shuffle=True
)
val_generator = val_datagen.flow_from_directory(
    val_path,
    target_size=target_size,
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Define the number of classes
num_classes = 7

# New Model architecture with additional convolutional layers
model = Sequential([
        Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1)),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(512, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(1024, activation='relu'),
        Dropout(0.5),
        Dense(1024, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

# Model compilation
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 23, 23, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 21, 21, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 256)         295168
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 512)         1180160
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 3,131,911
# Trainable params: 3,131,911
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# CNN Algorithm

# %%
# Define the number of classes
num_classes = 7

def create_model():
    # New Model architecture with additional convolutional layers
    model = Sequential([
        Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1)),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(512, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(1024, activation='relu'),
        Dropout(0.5),
        Dense(1024, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    # Model compilation
    optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

    return model

# %% [markdown]
# K-Fold Cross Validation & Confusion Matrix

# %%
# Define emotion labels
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
num_classes = len(emotion_labels)

# Initialize dictionaries to store metrics for each emotion
accuracy_dict = {emotion: [] for emotion in emotion_labels}
precision_dict = {emotion: [] for emotion in emotion_labels}
recall_dict = {emotion: [] for emotion in emotion_labels}
f1_score_dict = {emotion: [] for emotion in emotion_labels}

# Get the list of filenames and corresponding classes
filenames = train_generator.filenames
classes = train_generator.classes

# Initialize lists to store true and predicted labels
true_labels_all = []
pred_labels_all = []

# Split the data into training (80%) and test (20%) sets
train_files, test_files, train_classes, test_classes = train_test_split(
    filenames, classes, test_size=0.2, stratify=classes, random_state=42
)

# Use Stratified K-Fold Cross Validation on the training data
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Loop through each fold
for fold, (train_indices, val_indices) in enumerate(skf.split(train_files, train_classes)):
    print(f"Fold {fold+1}/{skf.n_splits}")

    # Split data into training and validation sets for the current fold
    fold_train_files = [train_files[i] for i in train_indices]
    fold_train_classes = [train_classes[i] for i in train_indices]
    fold_val_files = [train_files[i] for i in val_indices]
    fold_val_classes = [train_classes[i] for i in val_indices]

    # Create dataframes for the current fold
    train_df = pd.DataFrame({'filename': fold_train_files, 'class': fold_train_classes}).astype(str)
    val_df = pd.DataFrame({'filename': fold_val_files, 'class': fold_val_classes}).astype(str)

    # Create model for each fold
    model = create_model()

    # Create data generators for the current fold
    train_generator_fold = train_datagen.flow_from_dataframe(
        train_df,
        directory=train_path,
        x_col='filename',
        y_col='class',
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical',
        shuffle=True
    )
    
    val_generator_fold = val_datagen.flow_from_dataframe(
        val_df,
        directory=train_path,
        x_col='filename',
        y_col='class',
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical',
        shuffle=False
    )

    # Train the model
    history = model.fit(
        train_generator_fold,
        epochs=10,
        validation_data=val_generator_fold,
        verbose=1
    )

    # Evaluate the model on validation set for each fold
    val_metrics = model.evaluate(
        val_generator_fold,
        verbose=0
    )
    val_loss, val_acc, val_precision, val_recall = val_metrics[0], val_metrics[1], val_metrics[2], val_metrics[3]
    
    # Calculate F1-score
    if val_precision + val_recall == 0:
        val_f1_score = 0
    else:
        val_f1_score = 2 * (val_precision * val_recall) / (val_precision + val_recall)

    # Generate confusion matrix for this fold
    y_pred = model.predict(val_generator_fold)
    y_true = val_generator_fold.classes
    conf_matrix = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

    # Append true and predicted labels
    true_labels_all.extend(y_true)
    pred_labels_all.extend(np.argmax(y_pred, axis=1))

    # Calculate metrics for each emotion
    for i, emotion in enumerate(emotion_labels):
        tp = conf_matrix[i, i]
        fp = np.sum(conf_matrix[:, i]) - tp
        fn = np.sum(conf_matrix[i, :]) - tp
        tn = np.sum(conf_matrix) - (tp + fp + fn)

        accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) > 0 else 0
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        accuracy_dict[emotion].append(accuracy)
        precision_dict[emotion].append(precision)
        recall_dict[emotion].append(recall)
        f1_score_dict[emotion].append(f1_score)

    # Print metrics for each emotion
    for emotion in emotion_labels:
        print(f"Metrics for {emotion}:")
        print(f"Average Validation Accuracy: {np.mean(accuracy_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation Precision: {np.mean(precision_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation Recall: {np.mean(recall_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation F1-score: {np.mean(f1_score_dict[emotion]) * 100:.2f}%")
        print()

# Print overall average metrics
print("Overall Average Metrics:")
print(f"Average Validation Accuracy: {np.mean([np.mean(accuracy_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation Precision: {np.mean([np.mean(precision_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation Recall: {np.mean([np.mean(recall_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation F1-score: {np.mean([np.mean(f1_score_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")

# Generate the confusion matrix using accumulated true and predicted labels
cm = confusion_matrix(true_labels_all, pred_labels_all, labels=np.arange(num_classes))

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='PuRd', xticklabels=emotion_labels, yticklabels=emotion_labels)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show()

# Print the confusion matrix
print("Confusion Matrix:")
print(cm)
# Out:
# Fold 1/10
# Found 20670 validated image filenames belonging to 7 classes.
# Found 2297 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 677s 2s/step - loss: 1.8322 - accuracy: 0.2452 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.8150 - val_accuracy: 0.2512 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 633s 2s/step - loss: 1.8200 - accuracy: 0.2499 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.8132 - val_accuracy: 0.2512 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 651s 2s/step - loss: 1.8137 - accuracy: 0.2507 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.8006 - val_accuracy: 0.2512 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 644s 2s/step - loss: 1.7991 - accuracy: 0.2526 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7745 - val_accuracy: 0.2573 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 643s 2s/step - loss: 1.7895 - accuracy: 0.2528 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7744 - val_accuracy: 0.2608 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 673s 2s/step - loss: 1.7746 - accuracy: 0.2617 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7431 - val_accuracy: 0.2834 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 628s 2s/step - loss: 1.7344 - accuracy: 0.2930 - precision_1: 0.5033 - recall_1: 0.0037 - val_loss: 1.7036 - val_accuracy: 0.2987 - val_precision_1: 0.6435 - val_recall_1: 0.0644
# Epoch 8/10
# 323/323 [==============================] - 626s 2s/step - loss: 1.6914 - accuracy: 0.3168 - precision_1: 0.6141 - recall_1: 0.0346 - val_loss: 1.5995 - val_accuracy: 0.3814 - val_precision_1: 0.7500 - val_recall_1: 0.0535
# Epoch 9/10
# 323/323 [==============================] - 605s 2s/step - loss: 1.6568 - accuracy: 0.3387 - precision_1: 0.6271 - recall_1: 0.0714 - val_loss: 1.5645 - val_accuracy: 0.3814 - val_precision_1: 0.6279 - val_recall_1: 0.1859
# Epoch 10/10
# 323/323 [==============================] - 616s 2s/step - loss: 1.6143 - accuracy: 0.3644 - precision_1: 0.6658 - recall_1: 0.1031 - val_loss: 1.5080 - val_accuracy: 0.4131 - val_precision_1: 0.7877 - val_recall_1: 0.1502
# 36/36 [==============================] - 43s 468ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.20%
# Average Validation Precision: 29.52%
# Average Validation Recall: 9.69%
# Average Validation F1-score: 14.59%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 84.76%
# Average Validation Precision: 15.62%
# Average Validation Recall: 1.52%
# Average Validation F1-score: 2.78%
#
# Metrics for Happy:
# Average Validation Accuracy: 81.15%
# Average Validation Precision: 61.08%
# Average Validation Recall: 68.80%
# Average Validation F1-score: 64.71%
#
# Metrics for Sad:
# Average Validation Accuracy: 66.00%
# Average Validation Precision: 29.22%
# Average Validation Recall: 68.01%
# Average Validation F1-score: 40.88%
#
# Metrics for Surprise:
# Average Validation Accuracy: 80.24%
# Average Validation Precision: 34.12%
# Average Validation Recall: 18.60%
# Average Validation F1-score: 24.08%
#
# Metrics for Neutral:
# Average Validation Accuracy: 87.81%
# Average Validation Precision: 46.40%
# Average Validation Recall: 68.77%
# Average Validation F1-score: 55.41%
#
# Fold 2/10
# Found 20670 validated image filenames belonging to 7 classes.
# Found 2297 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 701s 2s/step - loss: 1.8310 - accuracy: 0.2473 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8131 - val_accuracy: 0.2512 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 648s 2s/step - loss: 1.8198 - accuracy: 0.2514 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8116 - val_accuracy: 0.2512 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 602s 2s/step - loss: 1.8113 - accuracy: 0.2508 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7975 - val_accuracy: 0.2577 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 616s 2s/step - loss: 1.7954 - accuracy: 0.2524 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8101 - val_accuracy: 0.2185 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 607s 2s/step - loss: 1.7907 - accuracy: 0.2526 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7913 - val_accuracy: 0.2547 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 684s 2s/step - loss: 1.7784 - accuracy: 0.2564 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7569 - val_accuracy: 0.2690 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 629s 2s/step - loss: 1.7542 - accuracy: 0.2743 - precision_2: 0.4167 - recall_2: 2.4190e-04 - val_loss: 1.7091 - val_accuracy: 0.3078 - val_precision_2: 0.5000 - val_recall_2: 8.7070e-04
# Epoch 8/10
# 323/323 [==============================] - 566s 2s/step - loss: 1.7214 - accuracy: 0.2980 - precision_2: 0.5270 - recall_2: 0.0080 - val_loss: 1.6683 - val_accuracy: 0.3526 - val_precision_2: 0.6842 - val_recall_2: 0.0113
# Epoch 9/10
# 323/323 [==============================] - 597s 2s/step - loss: 1.6841 - accuracy: 0.3242 - precision_2: 0.5636 - recall_2: 0.0330 - val_loss: 1.6122 - val_accuracy: 0.3722 - val_precision_2: 0.6861 - val_recall_2: 0.0818
# Epoch 10/10
# 323/323 [==============================] - 601s 2s/step - loss: 1.6446 - accuracy: 0.3482 - precision_2: 0.6313 - recall_2: 0.0745 - val_loss: 1.6030 - val_accuracy: 0.3653 - val_precision_2: 0.6268 - val_recall_2: 0.1302
# 36/36 [==============================] - 25s 531ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.83%
# Average Validation Precision: 29.05%
# Average Validation Recall: 11.09%
# Average Validation F1-score: 15.99%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 84.41%
# Average Validation Precision: 17.49%
# Average Validation Recall: 2.59%
# Average Validation F1-score: 4.47%
#
# Metrics for Happy:
# Average Validation Accuracy: 79.56%
# Average Validation Precision: 58.10%
# Average Validation Recall: 67.50%
# Average Validation F1-score: 62.43%
#
# Metrics for Sad:
# Average Validation Accuracy: 70.64%
# Average Validation Precision: 30.61%
# Average Validation Recall: 53.15%
# Average Validation F1-score: 37.87%
#
# Metrics for Surprise:
# Average Validation Accuracy: 80.21%
# Average Validation Precision: 33.12%
# Average Validation Recall: 17.33%
# Average Validation F1-score: 22.75%
#
# Metrics for Neutral:
# Average Validation Accuracy: 80.71%
# Average Validation Precision: 36.21%
# Average Validation Recall: 71.99%
# Average Validation F1-score: 47.04%
#
# Fold 3/10
# Found 20670 validated image filenames belonging to 7 classes.
# Found 2297 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 662s 2s/step - loss: 1.8337 - accuracy: 0.2445 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8173 - val_accuracy: 0.2512 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 582s 2s/step - loss: 1.8187 - accuracy: 0.2510 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8117 - val_accuracy: 0.2512 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 590s 2s/step - loss: 1.8112 - accuracy: 0.2515 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7964 - val_accuracy: 0.2512 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 595s 2s/step - loss: 1.7946 - accuracy: 0.2508 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7872 - val_accuracy: 0.2577 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 591s 2s/step - loss: 1.7853 - accuracy: 0.2525 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7569 - val_accuracy: 0.2730 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 582s 2s/step - loss: 1.7546 - accuracy: 0.2761 - precision_3: 0.3846 - recall_3: 2.4190e-04 - val_loss: 1.6950 - val_accuracy: 0.3209 - val_precision_3: 0.5600 - val_recall_3: 0.0061
# Epoch 7/10
# 323/323 [==============================] - 594s 2s/step - loss: 1.7126 - accuracy: 0.3054 - precision_3: 0.5449 - recall_3: 0.0138 - val_loss: 1.6360 - val_accuracy: 0.3448 - val_precision_3: 0.6093 - val_recall_3: 0.0570
# Epoch 8/10
# 323/323 [==============================] - 602s 2s/step - loss: 1.6738 - accuracy: 0.3302 - precision_3: 0.6170 - recall_3: 0.0539 - val_loss: 1.5762 - val_accuracy: 0.3879 - val_precision_3: 0.6859 - val_recall_3: 0.1141
# Epoch 9/10
# 323/323 [==============================] - 614s 2s/step - loss: 1.6276 - accuracy: 0.3567 - precision_3: 0.6568 - recall_3: 0.0944 - val_loss: 1.5379 - val_accuracy: 0.4131 - val_precision_3: 0.7802 - val_recall_3: 0.1097
# Epoch 10/10
# 323/323 [==============================] - 581s 2s/step - loss: 1.5913 - accuracy: 0.3741 - precision_3: 0.6905 - recall_3: 0.1177 - val_loss: 1.4863 - val_accuracy: 0.4279 - val_precision_3: 0.6864 - val_recall_3: 0.1916
# 36/36 [==============================] - 20s 430ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.41%
# Average Validation Precision: 31.30%
# Average Validation Recall: 17.92%
# Average Validation F1-score: 21.84%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 84.41%
# Average Validation Precision: 21.18%
# Average Validation Recall: 3.76%
# Average Validation F1-score: 6.33%
#
# Metrics for Happy:
# Average Validation Accuracy: 78.81%
# Average Validation Precision: 56.50%
# Average Validation Recall: 71.17%
# Average Validation F1-score: 62.79%
#
# Metrics for Sad:
# Average Validation Accuracy: 72.76%
# Average Validation Precision: 32.52%
# Average Validation Recall: 50.04%
# Average Validation F1-score: 38.49%
#
# Metrics for Surprise:
# Average Validation Accuracy: 81.02%
# Average Validation Precision: 36.83%
# Average Validation Recall: 15.87%
# Average Validation F1-score: 21.85%
#
# Metrics for Neutral:
# Average Validation Accuracy: 81.53%
# Average Validation Precision: 36.40%
# Average Validation Recall: 72.27%
# Average Validation F1-score: 47.65%
#
# Fold 4/10
# Found 20670 validated image filenames belonging to 7 classes.
# Found 2297 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 641s 2s/step - loss: 1.8338 - accuracy: 0.2449 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8132 - val_accuracy: 0.2516 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 571s 2s/step - loss: 1.8191 - accuracy: 0.2508 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8119 - val_accuracy: 0.2516 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 618s 2s/step - loss: 1.8116 - accuracy: 0.2517 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7938 - val_accuracy: 0.2516 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 605s 2s/step - loss: 1.7948 - accuracy: 0.2535 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7768 - val_accuracy: 0.2547 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 601s 2s/step - loss: 1.7867 - accuracy: 0.2515 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7720 - val_accuracy: 0.2516 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 617s 2s/step - loss: 1.7702 - accuracy: 0.2615 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7179 - val_accuracy: 0.3108 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 623s 2s/step - loss: 1.7283 - accuracy: 0.2936 - precision_4: 0.4975 - recall_4: 0.0048 - val_loss: 1.6495 - val_accuracy: 0.3600 - val_precision_4: 0.6620 - val_recall_4: 0.0205
# Epoch 8/10
# 323/323 [==============================] - 571s 2s/step - loss: 1.6781 - accuracy: 0.3259 - precision_4: 0.6060 - recall_4: 0.0458 - val_loss: 1.5940 - val_accuracy: 0.3465 - val_precision_4: 0.6102 - val_recall_4: 0.1663
# Epoch 9/10
# 323/323 [==============================] - 599s 2s/step - loss: 1.6365 - accuracy: 0.3498 - precision_4: 0.6497 - recall_4: 0.0873 - val_loss: 1.5228 - val_accuracy: 0.4105 - val_precision_4: 0.6978 - val_recall_4: 0.1498
# Epoch 10/10
# 323/323 [==============================] - 613s 2s/step - loss: 1.5942 - accuracy: 0.3700 - precision_4: 0.6893 - recall_4: 0.1146 - val_loss: 1.4878 - val_accuracy: 0.4162 - val_precision_4: 0.7129 - val_recall_4: 0.1946
# 36/36 [==============================] - 19s 380ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.46%
# Average Validation Precision: 32.08%
# Average Validation Recall: 18.45%
# Average Validation F1-score: 22.72%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.51%
# Average Validation Precision: 20.75%
# Average Validation Recall: 5.56%
# Average Validation F1-score: 8.25%
#
# Metrics for Happy:
# Average Validation Accuracy: 78.50%
# Average Validation Precision: 55.82%
# Average Validation Recall: 72.71%
# Average Validation F1-score: 62.95%
#
# Metrics for Sad:
# Average Validation Accuracy: 74.33%
# Average Validation Precision: 33.58%
# Average Validation Recall: 44.96%
# Average Validation F1-score: 37.08%
#
# Metrics for Surprise:
# Average Validation Accuracy: 80.75%
# Average Validation Precision: 36.50%
# Average Validation Recall: 17.86%
# Average Validation F1-score: 23.52%
#
# Metrics for Neutral:
# Average Validation Accuracy: 82.11%
# Average Validation Precision: 36.96%
# Average Validation Recall: 73.79%
# Average Validation F1-score: 48.68%
#
# Fold 5/10
# Found 20670 validated image filenames belonging to 7 classes.
# Found 2297 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 645s 2s/step - loss: 1.8335 - accuracy: 0.2440 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8149 - val_accuracy: 0.2516 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 578s 2s/step - loss: 1.8198 - accuracy: 0.2501 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8117 - val_accuracy: 0.2516 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 605s 2s/step - loss: 1.8127 - accuracy: 0.2503 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7979 - val_accuracy: 0.2516 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 572s 2s/step - loss: 1.7975 - accuracy: 0.2510 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7770 - val_accuracy: 0.2577 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 596s 2s/step - loss: 1.7885 - accuracy: 0.2521 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7646 - val_accuracy: 0.2608 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 592s 2s/step - loss: 1.7715 - accuracy: 0.2597 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7217 - val_accuracy: 0.3152 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 601s 2s/step - loss: 1.7320 - accuracy: 0.2914 - precision_5: 0.5405 - recall_5: 0.0058 - val_loss: 1.6369 - val_accuracy: 0.3539 - val_precision_5: 0.6710 - val_recall_5: 0.0453
# Epoch 8/10
# 323/323 [==============================] - 588s 2s/step - loss: 1.6897 - accuracy: 0.3159 - precision_5: 0.6074 - recall_5: 0.0372 - val_loss: 1.6299 - val_accuracy: 0.3653 - val_precision_5: 0.6776 - val_recall_5: 0.0897
# Epoch 9/10
# 323/323 [==============================] - 595s 2s/step - loss: 1.6527 - accuracy: 0.3414 - precision_5: 0.6318 - recall_5: 0.0739 - val_loss: 1.5506 - val_accuracy: 0.3970 - val_precision_5: 0.7654 - val_recall_5: 0.1136
# Epoch 10/10
# 323/323 [==============================] - 608s 2s/step - loss: 1.6098 - accuracy: 0.3657 - precision_5: 0.6685 - recall_5: 0.1072 - val_loss: 1.4796 - val_accuracy: 0.4214 - val_precision_5: 0.7300 - val_recall_5: 0.1789
# 36/36 [==============================] - 23s 496ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.75%
# Average Validation Precision: 33.32%
# Average Validation Recall: 17.52%
# Average Validation F1-score: 22.23%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.61%
# Average Validation Precision: 19.99%
# Average Validation Recall: 5.06%
# Average Validation F1-score: 7.64%
#
# Metrics for Happy:
# Average Validation Accuracy: 78.44%
# Average Validation Precision: 55.59%
# Average Validation Recall: 73.71%
# Average Validation F1-score: 63.20%
#
# Metrics for Sad:
# Average Validation Accuracy: 74.11%
# Average Validation Precision: 33.23%
# Average Validation Recall: 45.59%
# Average Validation F1-score: 37.33%
#
# Metrics for Surprise:
# Average Validation Accuracy: 80.02%
# Average Validation Precision: 35.20%
# Average Validation Recall: 19.73%
# Average Validation F1-score: 24.52%
#
# Metrics for Neutral:
# Average Validation Accuracy: 83.35%
# Average Validation Precision: 39.17%
# Average Validation Recall: 72.34%
# Average Validation F1-score: 50.10%
#
# Fold 6/10
# Found 20670 validated image filenames belonging to 7 classes.
# Found 2297 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 651s 2s/step - loss: 1.8307 - accuracy: 0.2460 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8206 - val_accuracy: 0.2512 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 616s 2s/step - loss: 1.8200 - accuracy: 0.2502 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8128 - val_accuracy: 0.2512 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 580s 2s/step - loss: 1.8090 - accuracy: 0.2517 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7973 - val_accuracy: 0.2551 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 586s 2s/step - loss: 1.7947 - accuracy: 0.2510 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7902 - val_accuracy: 0.2534 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 482s 1s/step - loss: 1.7850 - accuracy: 0.2561 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7771 - val_accuracy: 0.2643 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 458s 1s/step - loss: 1.7626 - accuracy: 0.2701 - precision_6: 0.3333 - recall_6: 4.8379e-05 - val_loss: 1.7363 - val_accuracy: 0.2934 - val_precision_6: 0.4000 - val_recall_6: 8.7070e-04
# Epoch 7/10
# 323/323 [==============================] - 452s 1s/step - loss: 1.7282 - accuracy: 0.2950 - precision_6: 0.5422 - recall_6: 0.0059 - val_loss: 1.6912 - val_accuracy: 0.3191 - val_precision_6: 0.5600 - val_recall_6: 0.0183
# Epoch 8/10
# 323/323 [==============================] - 470s 1s/step - loss: 1.6933 - accuracy: 0.3203 - precision_6: 0.5862 - recall_6: 0.0280 - val_loss: 1.6449 - val_accuracy: 0.3483 - val_precision_6: 0.6569 - val_recall_6: 0.0784
# Epoch 9/10
# 323/323 [==============================] - 474s 1s/step - loss: 1.6555 - accuracy: 0.3407 - precision_6: 0.6206 - recall_6: 0.0645 - val_loss: 1.5793 - val_accuracy: 0.3862 - val_precision_6: 0.6729 - val_recall_6: 0.1263
# Epoch 10/10
# 323/323 [==============================] - 498s 2s/step - loss: 1.6138 - accuracy: 0.3676 - precision_6: 0.6445 - recall_6: 0.0974 - val_loss: 1.6477 - val_accuracy: 0.3470 - val_precision_6: 0.5169 - val_recall_6: 0.2403
# 36/36 [==============================] - 21s 436ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.91%
# Average Validation Precision: 33.98%
# Average Validation Recall: 17.06%
# Average Validation F1-score: 22.05%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.78%
# Average Validation Precision: 19.36%
# Average Validation Recall: 4.52%
# Average Validation F1-score: 6.91%
#
# Metrics for Happy:
# Average Validation Accuracy: 73.97%
# Average Validation Precision: 51.91%
# Average Validation Recall: 77.08%
# Average Validation F1-score: 60.89%
#
# Metrics for Sad:
# Average Validation Accuracy: 75.43%
# Average Validation Precision: 34.01%
# Average Validation Recall: 38.91%
# Average Validation F1-score: 32.72%
#
# Metrics for Surprise:
# Average Validation Accuracy: 80.23%
# Average Validation Precision: 33.68%
# Average Validation Recall: 17.48%
# Average Validation F1-score: 22.11%
#
# Metrics for Neutral:
# Average Validation Accuracy: 83.90%
# Average Validation Precision: 39.77%
# Average Validation Recall: 70.52%
# Average Validation F1-score: 50.15%
#
# Fold 7/10
# Found 20670 validated image filenames belonging to 7 classes.
# Found 2297 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 495s 1s/step - loss: 1.8325 - accuracy: 0.2461 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8152 - val_accuracy: 0.2512 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 467s 1s/step - loss: 1.8196 - accuracy: 0.2499 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8128 - val_accuracy: 0.2512 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 435s 1s/step - loss: 1.8133 - accuracy: 0.2508 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8034 - val_accuracy: 0.2512 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 335s 1s/step - loss: 1.7972 - accuracy: 0.2528 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7953 - val_accuracy: 0.2582 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 322s 996ms/step - loss: 1.7884 - accuracy: 0.2517 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7775 - val_accuracy: 0.2582 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 340s 1s/step - loss: 1.7721 - accuracy: 0.2607 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7456 - val_accuracy: 0.2869 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 327s 1s/step - loss: 1.7325 - accuracy: 0.2925 - precision_7: 0.4759 - recall_7: 0.0033 - val_loss: 1.6703 - val_accuracy: 0.3335 - val_precision_7: 0.5862 - val_recall_7: 0.0074
# Epoch 8/10
# 323/323 [==============================] - 308s 951ms/step - loss: 1.6945 - accuracy: 0.3166 - precision_7: 0.5822 - recall_7: 0.0276 - val_loss: 1.6163 - val_accuracy: 0.3674 - val_precision_7: 0.6950 - val_recall_7: 0.0427
# Epoch 9/10
# 323/323 [==============================] - 337s 1s/step - loss: 1.6583 - accuracy: 0.3389 - precision_7: 0.6132 - recall_7: 0.0643 - val_loss: 1.5979 - val_accuracy: 0.3435 - val_precision_7: 0.6014 - val_recall_7: 0.1885
# Epoch 10/10
# 323/323 [==============================] - 337s 1s/step - loss: 1.6148 - accuracy: 0.3642 - precision_7: 0.6524 - recall_7: 0.1000 - val_loss: 1.4983 - val_accuracy: 0.4336 - val_precision_7: 0.7726 - val_recall_7: 0.1450
# 36/36 [==============================] - 7s 173ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.48%
# Average Validation Precision: 33.40%
# Average Validation Recall: 18.65%
# Average Validation F1-score: 23.04%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.82%
# Average Validation Precision: 20.35%
# Average Validation Recall: 4.79%
# Average Validation F1-score: 7.40%
#
# Metrics for Happy:
# Average Validation Accuracy: 74.69%
# Average Validation Precision: 52.50%
# Average Validation Recall: 77.01%
# Average Validation F1-score: 61.44%
#
# Metrics for Sad:
# Average Validation Accuracy: 75.96%
# Average Validation Precision: 34.79%
# Average Validation Recall: 38.78%
# Average Validation F1-score: 33.57%
#
# Metrics for Surprise:
# Average Validation Accuracy: 79.57%
# Average Validation Precision: 33.28%
# Average Validation Recall: 20.16%
# Average Validation F1-score: 23.71%
#
# Metrics for Neutral:
# Average Validation Accuracy: 84.71%
# Average Validation Precision: 41.57%
# Average Validation Recall: 68.99%
# Average Validation F1-score: 50.97%
#
# Fold 8/10
# Found 20671 validated image filenames belonging to 7 classes.
# Found 2296 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 358s 1s/step - loss: 1.8319 - accuracy: 0.2437 - precision_8: 1.0000 - recall_8: 4.8377e-05 - val_loss: 1.8152 - val_accuracy: 0.2513 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 328s 1s/step - loss: 1.8193 - accuracy: 0.2510 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8102 - val_accuracy: 0.2513 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 337s 1s/step - loss: 1.8147 - accuracy: 0.2506 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8026 - val_accuracy: 0.2513 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 341s 1s/step - loss: 1.8001 - accuracy: 0.2504 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7842 - val_accuracy: 0.2509 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 318s 983ms/step - loss: 1.7910 - accuracy: 0.2526 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7731 - val_accuracy: 0.2526 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 214s 661ms/step - loss: 1.7780 - accuracy: 0.2542 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7536 - val_accuracy: 0.2801 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 222s 686ms/step - loss: 1.7465 - accuracy: 0.2768 - precision_8: 0.4706 - recall_8: 0.0012 - val_loss: 1.6953 - val_accuracy: 0.3149 - val_precision_8: 0.6667 - val_recall_8: 0.0070
# Epoch 8/10
# 323/323 [==============================] - 220s 682ms/step - loss: 1.7188 - accuracy: 0.2983 - precision_8: 0.5702 - recall_8: 0.0098 - val_loss: 1.6615 - val_accuracy: 0.3210 - val_precision_8: 0.6907 - val_recall_8: 0.0875
# Epoch 9/10
# 323/323 [==============================] - 203s 628ms/step - loss: 1.6827 - accuracy: 0.3198 - precision_8: 0.5960 - recall_8: 0.0344 - val_loss: 1.5937 - val_accuracy: 0.3902 - val_precision_8: 0.7783 - val_recall_8: 0.0780
# Epoch 10/10
# 323/323 [==============================] - 214s 662ms/step - loss: 1.6399 - accuracy: 0.3461 - precision_8: 0.6444 - recall_8: 0.0794 - val_loss: 1.5268 - val_accuracy: 0.3946 - val_precision_8: 0.6904 - val_recall_8: 0.1816
# 36/36 [==============================] - 6s 159ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.68%
# Average Validation Precision: 33.87%
# Average Validation Recall: 17.57%
# Average Validation F1-score: 22.13%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.90%
# Average Validation Precision: 21.30%
# Average Validation Recall: 4.92%
# Average Validation F1-score: 7.67%
#
# Metrics for Happy:
# Average Validation Accuracy: 73.61%
# Average Validation Precision: 51.12%
# Average Validation Recall: 78.11%
# Average Validation F1-score: 60.75%
#
# Metrics for Sad:
# Average Validation Accuracy: 76.57%
# Average Validation Precision: 35.45%
# Average Validation Recall: 36.67%
# Average Validation F1-score: 32.91%
#
# Metrics for Surprise:
# Average Validation Accuracy: 78.95%
# Average Validation Precision: 32.47%
# Average Validation Recall: 21.29%
# Average Validation F1-score: 24.24%
#
# Metrics for Neutral:
# Average Validation Accuracy: 85.28%
# Average Validation Precision: 42.79%
# Average Validation Recall: 68.24%
# Average Validation F1-score: 51.66%
#
# Fold 9/10
# Found 20671 validated image filenames belonging to 7 classes.
# Found 2296 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 223s 673ms/step - loss: 1.8336 - accuracy: 0.2452 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8154 - val_accuracy: 0.2513 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 216s 668ms/step - loss: 1.8210 - accuracy: 0.2499 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8123 - val_accuracy: 0.2513 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 218s 674ms/step - loss: 1.8150 - accuracy: 0.2509 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8043 - val_accuracy: 0.2513 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 218s 674ms/step - loss: 1.8009 - accuracy: 0.2525 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7915 - val_accuracy: 0.2548 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 217s 672ms/step - loss: 1.7899 - accuracy: 0.2519 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7769 - val_accuracy: 0.2561 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 216s 668ms/step - loss: 1.7791 - accuracy: 0.2571 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7680 - val_accuracy: 0.2870 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 216s 669ms/step - loss: 1.7463 - accuracy: 0.2857 - precision_9: 0.3902 - recall_9: 0.0015 - val_loss: 1.6766 - val_accuracy: 0.3293 - val_precision_9: 0.7692 - val_recall_9: 0.0044
# Epoch 8/10
# 323/323 [==============================] - 121s 372ms/step - loss: 1.7072 - accuracy: 0.3113 - precision_9: 0.5708 - recall_9: 0.0197 - val_loss: 1.6210 - val_accuracy: 0.3558 - val_precision_9: 0.7315 - val_recall_9: 0.0475
# Epoch 9/10
# 323/323 [==============================] - 125s 385ms/step - loss: 1.6652 - accuracy: 0.3366 - precision_9: 0.6321 - recall_9: 0.0596 - val_loss: 1.5759 - val_accuracy: 0.3807 - val_precision_9: 0.7163 - val_recall_9: 0.1111
# Epoch 10/10
# 323/323 [==============================] - 123s 381ms/step - loss: 1.6282 - accuracy: 0.3557 - precision_9: 0.6501 - recall_9: 0.0923 - val_loss: 1.5347 - val_accuracy: 0.3933 - val_precision_9: 0.6951 - val_recall_9: 0.1807
# 36/36 [==============================] - 3s 83ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.85%
# Average Validation Precision: 34.51%
# Average Validation Recall: 16.87%
# Average Validation F1-score: 21.62%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.91%
# Average Validation Precision: 21.12%
# Average Validation Recall: 4.81%
# Average Validation F1-score: 7.56%
#
# Metrics for Happy:
# Average Validation Accuracy: 73.36%
# Average Validation Precision: 50.56%
# Average Validation Recall: 78.36%
# Average Validation F1-score: 60.51%
#
# Metrics for Sad:
# Average Validation Accuracy: 76.83%
# Average Validation Precision: 35.37%
# Average Validation Recall: 35.39%
# Average Validation F1-score: 32.50%
#
# Metrics for Surprise:
# Average Validation Accuracy: 78.65%
# Average Validation Precision: 32.13%
# Average Validation Recall: 22.20%
# Average Validation F1-score: 24.82%
#
# Metrics for Neutral:
# Average Validation Accuracy: 85.19%
# Average Validation Precision: 42.33%
# Average Validation Recall: 68.39%
# Average Validation F1-score: 51.45%
#
# Fold 10/10
# Found 20671 validated image filenames belonging to 7 classes.
# Found 2296 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 118s 360ms/step - loss: 1.8322 - accuracy: 0.2438 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8153 - val_accuracy: 0.2513 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 117s 361ms/step - loss: 1.8189 - accuracy: 0.2501 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8132 - val_accuracy: 0.2513 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 115s 357ms/step - loss: 1.8111 - accuracy: 0.2502 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7998 - val_accuracy: 0.2513 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 115s 357ms/step - loss: 1.7953 - accuracy: 0.2522 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7776 - val_accuracy: 0.2539 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 118s 364ms/step - loss: 1.7859 - accuracy: 0.2546 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7697 - val_accuracy: 0.2600 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 116s 358ms/step - loss: 1.7623 - accuracy: 0.2666 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7108 - val_accuracy: 0.2975 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 116s 359ms/step - loss: 1.7296 - accuracy: 0.2903 - precision_10: 0.4918 - recall_10: 0.0044 - val_loss: 1.6699 - val_accuracy: 0.3149 - val_precision_10: 0.5547 - val_recall_10: 0.0309
# Epoch 8/10
# 323/323 [==============================] - 126s 391ms/step - loss: 1.6917 - accuracy: 0.3152 - precision_10: 0.5846 - recall_10: 0.0272 - val_loss: 1.6063 - val_accuracy: 0.3606 - val_precision_10: 0.6580 - val_recall_10: 0.0997
# Epoch 9/10
# 323/323 [==============================] - 120s 372ms/step - loss: 1.6535 - accuracy: 0.3403 - precision_10: 0.6293 - recall_10: 0.0666 - val_loss: 1.5422 - val_accuracy: 0.4020 - val_precision_10: 0.7166 - val_recall_10: 0.1376
# Epoch 10/10
# 323/323 [==============================] - 118s 366ms/step - loss: 1.6093 - accuracy: 0.3694 - precision_10: 0.6651 - recall_10: 0.1046 - val_loss: 1.5118 - val_accuracy: 0.4251 - val_precision_10: 0.7756 - val_recall_10: 0.1189
# 36/36 [==============================] - 3s 90ms/step
# Metrics for Angry:
# Average Validation Accuracy: 82.94%
# Average Validation Precision: 33.59%
# Average Validation Recall: 19.37%
# Average Validation F1-score: 22.62%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.86%
# Average Validation Precision: 21.46%
# Average Validation Recall: 5.13%
# Average Validation F1-score: 8.00%
#
# Metrics for Happy:
# Average Validation Accuracy: 74.25%
# Average Validation Precision: 51.98%
# Average Validation Recall: 76.94%
# Average Validation F1-score: 60.90%
#
# Metrics for Sad:
# Average Validation Accuracy: 77.00%
# Average Validation Precision: 35.74%
# Average Validation Recall: 36.19%
# Average Validation F1-score: 33.36%
#
# Metrics for Surprise:
# Average Validation Accuracy: 78.76%
# Average Validation Precision: 32.37%
# Average Validation Recall: 22.18%
# Average Validation F1-score: 25.02%
#
# Metrics for Neutral:
# Average Validation Accuracy: 85.46%
# Average Validation Precision: 42.78%
# Average Validation Recall: 69.02%
# Average Validation F1-score: 52.06%
#
# Overall Average Metrics:
# Average Validation Accuracy: 82.96%
# Average Validation Precision: 31.13%
# Average Validation Recall: 32.69%
# Average Validation F1-score: 28.85%
# Confusion Matrix:
# [[ 619    0  134  893  611  550  389]
#  [  39    0   12  107   95   44   52]
#  [ 332    0  168  906  552  407  912]
#  [ 238    0  115 4441  403  233  342]
#  [ 270    0  110 1184 1437  539  432]
#  [ 400    0  151 1140  889  857  427]
#  [  63    0   75  353  198   97 1751]]
