# %% [markdown]
# Import Libraries and Packages

# %%
import os
import shutil
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import opendatasets as od
import tensorflow as tf
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %% [markdown]
# Data Extraction

# %%
# Download the dataset
dataset_url = 'https://www.kaggle.com/datasets/msambare/fer2013'
od.download(dataset_url)

# Define dataset paths
train_path = "fer2013/train"
val_path = "fer2013/test"
# Out:
# Skipping, found downloaded files in ".\fer2013" (use force=True to force download)

# %% [markdown]
# Data Pre-Processing

# %%
# Initialize data generators with data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
val_datagen = ImageDataGenerator(rescale=1./255)

# Load training and validation data
batch_size = 64
target_size = (48, 48)
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=target_size,
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical',
    shuffle=True
)
val_generator = val_datagen.flow_from_directory(
    val_path,
    target_size=target_size,
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Define the number of classes
num_classes = 7

# New Model architecture with additional convolutional layers
model = Sequential([
        Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1)),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(512, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(1024, activation='relu'),
        Dropout(0.5),
        Dense(1024, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

# Model compilation
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 46, 46, 64)        640
#
#  max_pooling2d_12 (MaxPoolin  (None, 23, 23, 64)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 21, 21, 128)       73856
#
#  max_pooling2d_13 (MaxPoolin  (None, 10, 10, 128)      0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 8, 8, 256)         295168
#
#  max_pooling2d_14 (MaxPoolin  (None, 4, 4, 256)        0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 2, 2, 512)         1180160
#
#  max_pooling2d_15 (MaxPoolin  (None, 1, 1, 512)        0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 512)               0
#
#  dense_9 (Dense)             (None, 1024)              525312
#
#  dropout_6 (Dropout)         (None, 1024)              0
#
#  dense_10 (Dense)            (None, 1024)              1049600
#
#  dropout_7 (Dropout)         (None, 1024)              0
#
#  dense_11 (Dense)            (None, 7)                 7175
#
# =================================================================
# Total params: 3,131,911
# Trainable params: 3,131,911
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# CNN Algorithm

# %%
# Define the number of classes
num_classes = 7

def create_model():
    # New Model architecture with additional convolutional layers
    model = Sequential([
        Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1)),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(512, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(1024, activation='relu'),
        Dropout(0.5),
        Dense(1024, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    # Model compilation
    optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

    return model

# %% [markdown]
# K-Fold Cross Validation & Confusion Matrix

# %%
# K-Fold Cross Validation with 80:20 split
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Define emotion labels
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# Initialize dictionaries to store metrics for each emotion
accuracy_dict = {emotion: [] for emotion in emotion_labels}
precision_dict = {emotion: [] for emotion in emotion_labels}
recall_dict = {emotion: [] for emotion in emotion_labels}
f1_score_dict = {emotion: [] for emotion in emotion_labels}

# Get the list of filenames and corresponding classes
filenames = train_generator.filenames
classes = train_generator.classes

# Initialize lists to store true and predicted labels
true_labels_all = []
pred_labels_all = []

# Loop through each fold
for fold, (train_indices, val_indices) in enumerate(skf.split(filenames, classes)):
    print(f"Fold {fold+1}/{skf.n_splits}")

    # Split data into training and validation sets for the current fold
    train_files = [filenames[i] for i in train_indices]
    train_classes = [classes[i] for i in train_indices]
    val_files = [filenames[i] for i in val_indices]
    val_classes = [classes[i] for i in val_indices]

    # Create dataframes for the current fold
    train_df = pd.DataFrame({'filename': train_files, 'class': train_classes}).astype(str)
    val_df = pd.DataFrame({'filename': val_files, 'class': val_classes}).astype(str)

    # Create model for each fold
    model = create_model()

    # Create data generators for the current fold
    train_generator_fold = train_datagen.flow_from_dataframe(
        train_df,
        directory=train_path,
        x_col='filename',
        y_col='class',
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical',
        shuffle=True
    )
    
    val_generator_fold = val_datagen.flow_from_dataframe(
        val_df,
        directory=train_path,
        x_col='filename',
        y_col='class',
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical',
        shuffle=False
    )

    # Train the model
    history = model.fit(
        train_generator_fold,
        epochs=10,
        validation_data=val_generator_fold,
        verbose=1
    )

    # Evaluate the model on validation set for each fold
    val_metrics = model.evaluate(
        val_generator_fold,
        verbose=0
    )
    val_loss, val_acc, val_precision, val_recall = val_metrics[0], val_metrics[1], val_metrics[2], val_metrics[3]
    
    # Calculate F1-score
    if val_precision + val_recall == 0:
        val_f1_score = 0
    else:
        val_f1_score = 2 * (val_precision * val_recall) / (val_precision + val_recall)

    # Generate confusion matrix for this fold
    y_pred = model.predict(val_generator_fold)
    y_true = val_generator_fold.classes
    conf_matrix = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

    # Append true and predicted labels
    true_labels_all.extend(y_true)
    pred_labels_all.extend(np.argmax(y_pred, axis=1))

    # Calculate metrics for each emotion
    for i, emotion in enumerate(emotion_labels):
        tp = conf_matrix[i, i]
        fp = np.sum(conf_matrix[:, i]) - tp
        fn = np.sum(conf_matrix[i, :]) - tp
        tn = np.sum(conf_matrix) - (tp + fp + fn)

        accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) > 0 else 0
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        accuracy_dict[emotion].append(accuracy)
        precision_dict[emotion].append(precision)
        recall_dict[emotion].append(recall)
        f1_score_dict[emotion].append(f1_score)

    # Print metrics for each emotion
    for emotion in emotion_labels:
        print(f"Metrics for {emotion}:")
        print(f"Average Validation Accuracy: {np.mean(accuracy_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation Precision: {np.mean(precision_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation Recall: {np.mean(recall_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation F1-score: {np.mean(f1_score_dict[emotion]) * 100:.2f}%")
        print()

# Print overall average metrics
print("Overall Average Metrics:")
print(f"Average Validation Accuracy: {np.mean([np.mean(accuracy_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation Precision: {np.mean([np.mean(precision_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation Recall: {np.mean([np.mean(recall_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation F1-score: {np.mean([np.mean(f1_score_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")

# Generate the confusion matrix using accumulated true and predicted labels
cm = confusion_matrix(true_labels_all, pred_labels_all, labels=np.arange(num_classes))

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='PuRd', xticklabels=emotion_labels, yticklabels=emotion_labels)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show()

# Print the confusion matrix
print("Confusion Matrix:")
print(cm)
# Out:
# Fold 1/10
# Found 25838 validated image filenames belonging to 7 classes.
# Found 2871 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 404/404 [==============================] - 175s 428ms/step - loss: 1.8298 - accuracy: 0.2479 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8211 - val_accuracy: 0.2515 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/10
# 404/404 [==============================] - 161s 398ms/step - loss: 1.8176 - accuracy: 0.2509 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8086 - val_accuracy: 0.2515 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 3/10
# 404/404 [==============================] - 161s 399ms/step - loss: 1.8007 - accuracy: 0.2523 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7775 - val_accuracy: 0.2609 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 4/10
# 404/404 [==============================] - 159s 394ms/step - loss: 1.7872 - accuracy: 0.2530 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7669 - val_accuracy: 0.2619 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 5/10
# 404/404 [==============================] - 179s 443ms/step - loss: 1.7613 - accuracy: 0.2679 - precision_4: 0.6364 - recall_4: 2.7092e-04 - val_loss: 1.7358 - val_accuracy: 0.2968 - val_precision_4: 0.3333 - val_recall_4: 0.0038
# Epoch 6/10
# 404/404 [==============================] - 175s 433ms/step - loss: 1.7099 - accuracy: 0.3067 - precision_4: 0.5807 - recall_4: 0.0177 - val_loss: 1.6180 - val_accuracy: 0.3741 - val_precision_4: 0.6855 - val_recall_4: 0.0592
# Epoch 7/10
# 404/404 [==============================] - 171s 424ms/step - loss: 1.6607 - accuracy: 0.3421 - precision_4: 0.6139 - recall_4: 0.0661 - val_loss: 1.5477 - val_accuracy: 0.3988 - val_precision_4: 0.7051 - val_recall_4: 0.1449
# Epoch 8/10
# 404/404 [==============================] - 165s 408ms/step - loss: 1.6032 - accuracy: 0.3680 - precision_4: 0.6700 - recall_4: 0.1072 - val_loss: 1.4857 - val_accuracy: 0.4208 - val_precision_4: 0.7220 - val_recall_4: 0.1818
# Epoch 9/10
# 404/404 [==============================] - 164s 405ms/step - loss: 1.5562 - accuracy: 0.3924 - precision_4: 0.7054 - recall_4: 0.1336 - val_loss: 1.4567 - val_accuracy: 0.4385 - val_precision_4: 0.7234 - val_recall_4: 0.2104
# Epoch 10/10
# 404/404 [==============================] - 168s 415ms/step - loss: 1.5007 - accuracy: 0.4188 - precision_4: 0.7216 - recall_4: 0.1609 - val_loss: 1.3890 - val_accuracy: 0.4758 - val_precision_4: 0.7828 - val_recall_4: 0.1996
# 45/45 [==============================] - 5s 91ms/step
# Metrics for Angry:
# Average Validation Accuracy: 81.78%
# Average Validation Precision: 34.96%
# Average Validation Recall: 35.75%
# Average Validation F1-score: 35.35%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 82.93%
# Average Validation Precision: 20.00%
# Average Validation Recall: 6.60%
# Average Validation F1-score: 9.93%
#
# Metrics for Happy:
# Average Validation Accuracy: 85.48%
# Average Validation Precision: 70.09%
# Average Validation Recall: 73.68%
# Average Validation F1-score: 71.84%
#
# Metrics for Sad:
# Average Validation Accuracy: 77.15%
# Average Validation Precision: 38.73%
# Average Validation Recall: 55.44%
# Average Validation F1-score: 45.61%
#
# Metrics for Surprise:
# Average Validation Accuracy: 80.70%
# Average Validation Precision: 40.38%
# Average Validation Recall: 30.85%
# Average Validation F1-score: 34.98%
#
# Metrics for Neutral:
# Average Validation Accuracy: 88.65%
# Average Validation Precision: 49.08%
# Average Validation Recall: 75.71%
# Average Validation F1-score: 59.55%
#
# Fold 2/10
# Found 25838 validated image filenames belonging to 7 classes.
# Found 2871 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 404/404 [==============================] - 163s 399ms/step - loss: 1.8300 - accuracy: 0.2434 - precision_5: 0.6667 - recall_5: 7.7405e-05 - val_loss: 1.8159 - val_accuracy: 0.2515 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 2/10
# 404/404 [==============================] - 157s 389ms/step - loss: 1.8189 - accuracy: 0.2508 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8090 - val_accuracy: 0.2515 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 3/10
# 404/404 [==============================] - 157s 389ms/step - loss: 1.8041 - accuracy: 0.2500 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7922 - val_accuracy: 0.2546 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 4/10
# 404/404 [==============================] - 160s 397ms/step - loss: 1.7885 - accuracy: 0.2521 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7859 - val_accuracy: 0.2494 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 5/10
# 404/404 [==============================] - 156s 387ms/step - loss: 1.7738 - accuracy: 0.2600 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7830 - val_accuracy: 0.2306 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 6/10
# 404/404 [==============================] - 153s 379ms/step - loss: 1.7348 - accuracy: 0.2842 - precision_5: 0.5411 - recall_5: 0.0043 - val_loss: 1.6610 - val_accuracy: 0.3305 - val_precision_5: 0.6571 - val_recall_5: 0.0160
# Epoch 7/10
# 404/404 [==============================] - 155s 384ms/step - loss: 1.6921 - accuracy: 0.3148 - precision_5: 0.5905 - recall_5: 0.0302 - val_loss: 1.5925 - val_accuracy: 0.3845 - val_precision_5: 0.7483 - val_recall_5: 0.0787
# Epoch 8/10
# 404/404 [==============================] - 153s 378ms/step - loss: 1.6394 - accuracy: 0.3468 - precision_5: 0.6371 - recall_5: 0.0786 - val_loss: 1.5357 - val_accuracy: 0.3971 - val_precision_5: 0.6550 - val_recall_5: 0.1884
# Epoch 9/10
# 404/404 [==============================] - 152s 376ms/step - loss: 1.5872 - accuracy: 0.3756 - precision_5: 0.6844 - recall_5: 0.1163 - val_loss: 1.4903 - val_accuracy: 0.4298 - val_precision_5: 0.6656 - val_recall_5: 0.2107
# Epoch 10/10
# 404/404 [==============================] - 156s 387ms/step - loss: 1.5343 - accuracy: 0.3998 - precision_5: 0.7116 - recall_5: 0.1442 - val_loss: 1.4091 - val_accuracy: 0.4636 - val_precision_5: 0.7338 - val_recall_5: 0.2170
# 45/45 [==============================] - 5s 95ms/step
# Metrics for Angry:
# Average Validation Accuracy: 81.40%
# Average Validation Precision: 34.15%
# Average Validation Recall: 36.00%
# Average Validation F1-score: 35.04%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.56%
# Average Validation Precision: 24.42%
# Average Validation Recall: 6.96%
# Average Validation F1-score: 10.80%
#
# Metrics for Happy:
# Average Validation Accuracy: 82.78%
# Average Validation Precision: 63.58%
# Average Validation Recall: 78.81%
# Average Validation F1-score: 69.89%
#
# Metrics for Sad:
# Average Validation Accuracy: 77.74%
# Average Validation Precision: 38.90%
# Average Validation Recall: 50.40%
# Average Validation F1-score: 43.79%
#
# Metrics for Surprise:
# Average Validation Accuracy: 80.77%
# Average Validation Precision: 39.27%
# Average Validation Recall: 26.60%
# Average Validation F1-score: 31.59%
#
# Metrics for Neutral:
# Average Validation Accuracy: 89.20%
# Average Validation Precision: 50.94%
# Average Validation Recall: 72.08%
# Average Validation F1-score: 59.58%
#
# Fold 3/10
# Found 25838 validated image filenames belonging to 7 classes.
# Found 2871 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 404/404 [==============================] - 156s 381ms/step - loss: 1.8311 - accuracy: 0.2451 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8178 - val_accuracy: 0.2515 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 2/10
# 404/404 [==============================] - 171s 424ms/step - loss: 1.8191 - accuracy: 0.2499 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8119 - val_accuracy: 0.2515 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 3/10
# 404/404 [==============================] - 165s 409ms/step - loss: 1.8055 - accuracy: 0.2510 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7880 - val_accuracy: 0.2515 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 4/10
# 404/404 [==============================] - 160s 395ms/step - loss: 1.7906 - accuracy: 0.2533 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7735 - val_accuracy: 0.2536 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 5/10
# 404/404 [==============================] - 154s 380ms/step - loss: 1.7775 - accuracy: 0.2571 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7279 - val_accuracy: 0.2853 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 6/10
# 404/404 [==============================] - 153s 378ms/step - loss: 1.7358 - accuracy: 0.2877 - precision_6: 0.5329 - recall_6: 0.0031 - val_loss: 1.6579 - val_accuracy: 0.3365 - val_precision_6: 0.5301 - val_recall_6: 0.0307
# Epoch 7/10
# 404/404 [==============================] - 156s 385ms/step - loss: 1.6897 - accuracy: 0.3207 - precision_6: 0.6070 - recall_6: 0.0337 - val_loss: 1.5927 - val_accuracy: 0.3525 - val_precision_6: 0.6716 - val_recall_6: 0.1581
# Epoch 8/10
# 404/404 [==============================] - 154s 381ms/step - loss: 1.6364 - accuracy: 0.3490 - precision_6: 0.6454 - recall_6: 0.0848 - val_loss: 1.5446 - val_accuracy: 0.3978 - val_precision_6: 0.6552 - val_recall_6: 0.1794
# Epoch 9/10
# 404/404 [==============================] - 154s 382ms/step - loss: 1.5849 - accuracy: 0.3787 - precision_6: 0.6879 - recall_6: 0.1193 - val_loss: 1.4531 - val_accuracy: 0.4469 - val_precision_6: 0.7626 - val_recall_6: 0.1745
# Epoch 10/10
# 404/404 [==============================] - 155s 385ms/step - loss: 1.5298 - accuracy: 0.4049 - precision_6: 0.7098 - recall_6: 0.1475 - val_loss: 1.5170 - val_accuracy: 0.4134 - val_precision_6: 0.6567 - val_recall_6: 0.1752
# 45/45 [==============================] - 5s 98ms/step
# Metrics for Angry:
# Average Validation Accuracy: 80.36%
# Average Validation Precision: 32.39%
# Average Validation Recall: 36.75%
# Average Validation F1-score: 34.33%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.49%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.06%
# Average Validation Precision: 25.44%
# Average Validation Recall: 9.84%
# Average Validation F1-score: 13.84%
#
# Metrics for Happy:
# Average Validation Accuracy: 83.58%
# Average Validation Precision: 67.37%
# Average Validation Recall: 73.13%
# Average Validation F1-score: 69.17%
#
# Metrics for Sad:
# Average Validation Accuracy: 78.81%
# Average Validation Precision: 40.63%
# Average Validation Recall: 46.37%
# Average Validation F1-score: 42.86%
#
# Metrics for Surprise:
# Average Validation Accuracy: 81.02%
# Average Validation Precision: 38.20%
# Average Validation Recall: 22.02%
# Average Validation F1-score: 27.37%
#
# Metrics for Neutral:
# Average Validation Accuracy: 84.87%
# Average Validation Precision: 43.92%
# Average Validation Recall: 76.66%
# Average Validation F1-score: 54.50%
#
# Fold 4/10
# Found 25838 validated image filenames belonging to 7 classes.
# Found 2871 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 404/404 [==============================] - 158s 386ms/step - loss: 1.8302 - accuracy: 0.2467 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8140 - val_accuracy: 0.2511 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 2/10
# 404/404 [==============================] - 155s 382ms/step - loss: 1.8177 - accuracy: 0.2509 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8100 - val_accuracy: 0.2511 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 3/10
# 404/404 [==============================] - 153s 378ms/step - loss: 1.8046 - accuracy: 0.2505 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7834 - val_accuracy: 0.2546 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 4/10
# 404/404 [==============================] - 7118s 18s/step - loss: 1.7910 - accuracy: 0.2539 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7727 - val_accuracy: 0.2557 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 5/10
# 404/404 [==============================] - 186s 460ms/step - loss: 1.7789 - accuracy: 0.2567 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7492 - val_accuracy: 0.2682 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 6/10
# 404/404 [==============================] - 172s 424ms/step - loss: 1.7448 - accuracy: 0.2837 - precision_7: 0.4923 - recall_7: 0.0012 - val_loss: 1.6626 - val_accuracy: 0.3288 - val_precision_7: 0.5652 - val_recall_7: 0.0091
# Epoch 7/10
# 404/404 [==============================] - 169s 419ms/step - loss: 1.6960 - accuracy: 0.3167 - precision_7: 0.5905 - recall_7: 0.0279 - val_loss: 1.6040 - val_accuracy: 0.3689 - val_precision_7: 0.6789 - val_recall_7: 0.0773
# Epoch 8/10
# 404/404 [==============================] - 171s 424ms/step - loss: 1.6486 - accuracy: 0.3428 - precision_7: 0.6387 - recall_7: 0.0781 - val_loss: 1.5390 - val_accuracy: 0.4100 - val_precision_7: 0.6846 - val_recall_7: 0.1595
# Epoch 9/10
# 404/404 [==============================] - 171s 423ms/step - loss: 1.6014 - accuracy: 0.3714 - precision_7: 0.6657 - recall_7: 0.1101 - val_loss: 1.4959 - val_accuracy: 0.4277 - val_precision_7: 0.6762 - val_recall_7: 0.1884
# Epoch 10/10
# 404/404 [==============================] - 171s 423ms/step - loss: 1.5554 - accuracy: 0.3937 - precision_7: 0.7094 - recall_7: 0.1369 - val_loss: 1.4244 - val_accuracy: 0.4688 - val_precision_7: 0.7132 - val_recall_7: 0.2191
# 45/45 [==============================] - 5s 101ms/step
# Metrics for Angry:
# Average Validation Accuracy: 81.50%
# Average Validation Precision: 34.49%
# Average Validation Recall: 32.12%
# Average Validation F1-score: 32.05%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.49%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.54%
# Average Validation Precision: 25.75%
# Average Validation Recall: 8.11%
# Average Validation F1-score: 11.70%
#
# Metrics for Happy:
# Average Validation Accuracy: 82.45%
# Average Validation Precision: 64.42%
# Average Validation Recall: 75.58%
# Average Validation F1-score: 68.52%
#
# Metrics for Sad:
# Average Validation Accuracy: 78.39%
# Average Validation Precision: 40.30%
# Average Validation Recall: 49.62%
# Average Validation F1-score: 43.97%
#
# Metrics for Surprise:
# Average Validation Accuracy: 80.98%
# Average Validation Precision: 38.68%
# Average Validation Recall: 23.45%
# Average Validation F1-score: 28.73%
#
# Metrics for Neutral:
# Average Validation Accuracy: 85.73%
# Average Validation Precision: 44.95%
# Average Validation Recall: 75.95%
# Average Validation F1-score: 55.43%
#
# Fold 5/10
# Found 25838 validated image filenames belonging to 7 classes.
# Found 2871 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 404/404 [==============================] - 175s 424ms/step - loss: 1.8310 - accuracy: 0.2461 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8159 - val_accuracy: 0.2511 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 2/10
# 404/404 [==============================] - 168s 416ms/step - loss: 1.8160 - accuracy: 0.2504 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8064 - val_accuracy: 0.2511 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 3/10
# 404/404 [==============================] - 169s 418ms/step - loss: 1.7970 - accuracy: 0.2525 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7847 - val_accuracy: 0.2508 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 4/10
# 404/404 [==============================] - 169s 418ms/step - loss: 1.7830 - accuracy: 0.2548 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7703 - val_accuracy: 0.2609 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 5/10
# 404/404 [==============================] - 170s 420ms/step - loss: 1.7509 - accuracy: 0.2790 - precision_8: 0.4167 - recall_8: 5.8054e-04 - val_loss: 1.6978 - val_accuracy: 0.3177 - val_precision_8: 0.7273 - val_recall_8: 0.0028
# Epoch 6/10
# 404/404 [==============================] - 170s 420ms/step - loss: 1.7042 - accuracy: 0.3133 - precision_8: 0.5708 - recall_8: 0.0240 - val_loss: 1.6306 - val_accuracy: 0.3521 - val_precision_8: 0.7150 - val_recall_8: 0.0533
# Epoch 7/10
# 404/404 [==============================] - 170s 421ms/step - loss: 1.6562 - accuracy: 0.3453 - precision_8: 0.6241 - recall_8: 0.0692 - val_loss: 1.6367 - val_accuracy: 0.3535 - val_precision_8: 0.5756 - val_recall_8: 0.1937
# Epoch 8/10
# 404/404 [==============================] - 170s 421ms/step - loss: 1.6046 - accuracy: 0.3686 - precision_8: 0.6723 - recall_8: 0.1089 - val_loss: 1.5055 - val_accuracy: 0.4190 - val_precision_8: 0.7116 - val_recall_8: 0.1839
# Epoch 9/10
# 404/404 [==============================] - 169s 419ms/step - loss: 1.5591 - accuracy: 0.3916 - precision_8: 0.7026 - recall_8: 0.1327 - val_loss: 1.5260 - val_accuracy: 0.4051 - val_precision_8: 0.6707 - val_recall_8: 0.1724
# Epoch 10/10
# 404/404 [==============================] - 170s 420ms/step - loss: 1.5111 - accuracy: 0.4157 - precision_8: 0.7167 - recall_8: 0.1570 - val_loss: 1.3969 - val_accuracy: 0.4646 - val_precision_8: 0.7994 - val_recall_8: 0.1985
# 45/45 [==============================] - 5s 103ms/step
# Metrics for Angry:
# Average Validation Accuracy: 81.56%
# Average Validation Precision: 34.67%
# Average Validation Recall: 33.10%
# Average Validation F1-score: 32.88%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.50%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.77%
# Average Validation Precision: 27.19%
# Average Validation Recall: 7.91%
# Average Validation F1-score: 11.69%
#
# Metrics for Happy:
# Average Validation Accuracy: 82.53%
# Average Validation Precision: 64.15%
# Average Validation Recall: 75.75%
# Average Validation F1-score: 68.63%
#
# Metrics for Sad:
# Average Validation Accuracy: 78.12%
# Average Validation Precision: 39.85%
# Average Validation Recall: 50.08%
# Average Validation F1-score: 43.96%
#
# Metrics for Surprise:
# Average Validation Accuracy: 80.36%
# Average Validation Precision: 37.68%
# Average Validation Recall: 25.30%
# Average Validation F1-score: 29.62%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.62%
# Average Validation Precision: 47.01%
# Average Validation Recall: 72.74%
# Average Validation F1-score: 55.84%
#
# Fold 6/10
# Found 25838 validated image filenames belonging to 7 classes.
# Found 2871 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 404/404 [==============================] - 176s 427ms/step - loss: 1.8312 - accuracy: 0.2465 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8152 - val_accuracy: 0.2511 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 2/10
# 404/404 [==============================] - 176s 436ms/step - loss: 1.8174 - accuracy: 0.2507 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8073 - val_accuracy: 0.2511 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 3/10
# 404/404 [==============================] - 159s 394ms/step - loss: 1.8011 - accuracy: 0.2507 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7806 - val_accuracy: 0.2574 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 4/10
# 404/404 [==============================] - 184s 456ms/step - loss: 1.7886 - accuracy: 0.2538 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7698 - val_accuracy: 0.2588 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 5/10
# 404/404 [==============================] - 172s 425ms/step - loss: 1.7696 - accuracy: 0.2640 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7053 - val_accuracy: 0.2995 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 6/10
# 404/404 [==============================] - 192s 476ms/step - loss: 1.7222 - accuracy: 0.2996 - precision_9: 0.5652 - recall_9: 0.0091 - val_loss: 1.6428 - val_accuracy: 0.3389 - val_precision_9: 0.6480 - val_recall_9: 0.0885
# Epoch 7/10
# 404/404 [==============================] - 494s 1s/step - loss: 1.6702 - accuracy: 0.3347 - precision_9: 0.6023 - recall_9: 0.0549 - val_loss: 1.6075 - val_accuracy: 0.3605 - val_precision_9: 0.6559 - val_recall_9: 0.1627
# Epoch 8/10
# 404/404 [==============================] - 775s 2s/step - loss: 1.6221 - accuracy: 0.3565 - precision_9: 0.6670 - recall_9: 0.0971 - val_loss: 1.5070 - val_accuracy: 0.4068 - val_precision_9: 0.6835 - val_recall_9: 0.2212
# Epoch 9/10
# 404/404 [==============================] - 802s 2s/step - loss: 1.5615 - accuracy: 0.3880 - precision_9: 0.7051 - recall_9: 0.1307 - val_loss: 1.4515 - val_accuracy: 0.4399 - val_precision_9: 0.7552 - val_recall_9: 0.1891
# Epoch 10/10
# 404/404 [==============================] - 809s 2s/step - loss: 1.5041 - accuracy: 0.4168 - precision_9: 0.7244 - recall_9: 0.1566 - val_loss: 1.3884 - val_accuracy: 0.4671 - val_precision_9: 0.7978 - val_recall_9: 0.1992
# 45/45 [==============================] - 33s 623ms/step
# Metrics for Angry:
# Average Validation Accuracy: 81.59%
# Average Validation Precision: 34.45%
# Average Validation Recall: 32.85%
# Average Validation F1-score: 32.80%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.49%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.21%
# Average Validation Precision: 26.04%
# Average Validation Recall: 8.70%
# Average Validation F1-score: 12.34%
#
# Metrics for Happy:
# Average Validation Accuracy: 83.45%
# Average Validation Precision: 66.71%
# Average Validation Recall: 74.89%
# Average Validation F1-score: 69.66%
#
# Metrics for Sad:
# Average Validation Accuracy: 77.75%
# Average Validation Precision: 39.55%
# Average Validation Recall: 52.09%
# Average Validation F1-score: 44.50%
#
# Metrics for Surprise:
# Average Validation Accuracy: 80.34%
# Average Validation Precision: 37.43%
# Average Validation Recall: 24.88%
# Average Validation F1-score: 29.34%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.95%
# Average Validation Precision: 47.32%
# Average Validation Recall: 72.98%
# Average Validation F1-score: 56.35%
#
# Fold 7/10
# Found 25838 validated image filenames belonging to 7 classes.
# Found 2871 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 404/404 [==============================] - 832s 2s/step - loss: 1.8281 - accuracy: 0.2467 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8149 - val_accuracy: 0.2511 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 2/10
# 404/404 [==============================] - 776s 2s/step - loss: 1.8163 - accuracy: 0.2507 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8044 - val_accuracy: 0.2511 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 3/10
# 404/404 [==============================] - 750s 2s/step - loss: 1.7984 - accuracy: 0.2491 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7845 - val_accuracy: 0.2518 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 4/10
# 404/404 [==============================] - 757s 2s/step - loss: 1.7866 - accuracy: 0.2549 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7876 - val_accuracy: 0.2529 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 5/10
# 404/404 [==============================] - 762s 2s/step - loss: 1.7649 - accuracy: 0.2671 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7228 - val_accuracy: 0.3121 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 6/10
# 404/404 [==============================] - 813s 2s/step - loss: 1.7133 - accuracy: 0.3044 - precision_10: 0.5774 - recall_10: 0.0166 - val_loss: 1.6630 - val_accuracy: 0.3424 - val_precision_10: 0.6455 - val_recall_10: 0.0247
# Epoch 7/10
# 404/404 [==============================] - 787s 2s/step - loss: 1.6661 - accuracy: 0.3356 - precision_10: 0.6226 - recall_10: 0.0634 - val_loss: 1.5738 - val_accuracy: 0.3957 - val_precision_10: 0.7396 - val_recall_10: 0.0871
# Epoch 8/10
# 404/404 [==============================] - 788s 2s/step - loss: 1.6228 - accuracy: 0.3596 - precision_10: 0.6605 - recall_10: 0.0972 - val_loss: 1.4985 - val_accuracy: 0.4249 - val_precision_10: 0.7549 - val_recall_10: 0.1609
# Epoch 9/10
# 404/404 [==============================] - 821s 2s/step - loss: 1.5756 - accuracy: 0.3862 - precision_10: 0.6928 - recall_10: 0.1260 - val_loss: 1.4689 - val_accuracy: 0.4420 - val_precision_10: 0.8236 - val_recall_10: 0.1627
# Epoch 10/10
# 404/404 [==============================] - 827s 2s/step - loss: 1.5253 - accuracy: 0.4088 - precision_10: 0.7096 - recall_10: 0.1485 - val_loss: 1.4298 - val_accuracy: 0.4444 - val_precision_10: 0.7517 - val_recall_10: 0.2268
# 45/45 [==============================] - 32s 566ms/step
# Metrics for Angry:
# Average Validation Accuracy: 81.81%
# Average Validation Precision: 34.43%
# Average Validation Recall: 31.48%
# Average Validation F1-score: 32.08%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.49%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 82.94%
# Average Validation Precision: 25.24%
# Average Validation Recall: 8.99%
# Average Validation F1-score: 12.59%
#
# Metrics for Happy:
# Average Validation Accuracy: 83.27%
# Average Validation Precision: 65.85%
# Average Validation Recall: 75.92%
# Average Validation F1-score: 69.68%
#
# Metrics for Sad:
# Average Validation Accuracy: 77.96%
# Average Validation Precision: 39.61%
# Average Validation Recall: 50.40%
# Average Validation F1-score: 43.87%
#
# Metrics for Surprise:
# Average Validation Accuracy: 80.40%
# Average Validation Precision: 37.36%
# Average Validation Recall: 24.25%
# Average Validation F1-score: 28.92%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.52%
# Average Validation Precision: 46.09%
# Average Validation Recall: 73.73%
# Average Validation F1-score: 55.70%
#
# Fold 8/10
# Found 25838 validated image filenames belonging to 7 classes.
# Found 2871 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 404/404 [==============================] - 782s 2s/step - loss: 1.8286 - accuracy: 0.2467 - precision_11: 0.0000e+00 - recall_11: 0.0000e+00 - val_loss: 1.8174 - val_accuracy: 0.2511 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00
# Epoch 2/10
# 404/404 [==============================] - 726s 2s/step - loss: 1.8174 - accuracy: 0.2510 - precision_11: 0.0000e+00 - recall_11: 0.0000e+00 - val_loss: 1.8077 - val_accuracy: 0.2511 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00
# Epoch 3/10
# 404/404 [==============================] - 726s 2s/step - loss: 1.8012 - accuracy: 0.2515 - precision_11: 0.0000e+00 - recall_11: 0.0000e+00 - val_loss: 1.7802 - val_accuracy: 0.2557 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00
# Epoch 4/10
# 404/404 [==============================] - 733s 2s/step - loss: 1.7879 - accuracy: 0.2523 - precision_11: 0.0000e+00 - recall_11: 0.0000e+00 - val_loss: 1.7652 - val_accuracy: 0.2605 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00
# Epoch 5/10
# 404/404 [==============================] - 730s 2s/step - loss: 1.7665 - accuracy: 0.2624 - precision_11: 0.0000e+00 - recall_11: 0.0000e+00 - val_loss: 1.7195 - val_accuracy: 0.3013 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00
# Epoch 6/10
# 404/404 [==============================] - 742s 2s/step - loss: 1.7277 - accuracy: 0.2943 - precision_11: 0.5376 - recall_11: 0.0058 - val_loss: 1.6480 - val_accuracy: 0.3312 - val_precision_11: 0.7280 - val_recall_11: 0.0317
# Epoch 7/10
# 404/404 [==============================] - 722s 2s/step - loss: 1.6782 - accuracy: 0.3290 - precision_11: 0.6141 - recall_11: 0.0404 - val_loss: 1.5899 - val_accuracy: 0.3741 - val_precision_11: 0.6631 - val_recall_11: 0.1310
# Epoch 8/10
# 404/404 [==============================] - 716s 2s/step - loss: 1.6358 - accuracy: 0.3558 - precision_11: 0.6369 - recall_11: 0.0857 - val_loss: 1.5515 - val_accuracy: 0.3859 - val_precision_11: 0.6458 - val_recall_11: 0.1944
# Epoch 9/10
# 404/404 [==============================] - 737s 2s/step - loss: 1.5879 - accuracy: 0.3797 - precision_11: 0.6752 - recall_11: 0.1157 - val_loss: 1.4620 - val_accuracy: 0.4350 - val_precision_11: 0.7532 - val_recall_11: 0.1818
# Epoch 10/10
# 404/404 [==============================] - 748s 2s/step - loss: 1.5416 - accuracy: 0.3998 - precision_11: 0.7130 - recall_11: 0.1425 - val_loss: 1.4221 - val_accuracy: 0.4514 - val_precision_11: 0.7460 - val_recall_11: 0.2107
# 45/45 [==============================] - 32s 578ms/step
# Metrics for Angry:
# Average Validation Accuracy: 81.71%
# Average Validation Precision: 34.17%
# Average Validation Recall: 31.75%
# Average Validation F1-score: 32.19%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 82.88%
# Average Validation Precision: 24.47%
# Average Validation Recall: 8.75%
# Average Validation F1-score: 12.31%
#
# Metrics for Happy:
# Average Validation Accuracy: 82.75%
# Average Validation Precision: 64.57%
# Average Validation Recall: 76.87%
# Average Validation F1-score: 69.31%
#
# Metrics for Sad:
# Average Validation Accuracy: 78.27%
# Average Validation Precision: 39.98%
# Average Validation Recall: 48.65%
# Average Validation F1-score: 43.29%
#
# Metrics for Surprise:
# Average Validation Accuracy: 80.16%
# Average Validation Precision: 36.96%
# Average Validation Recall: 24.95%
# Average Validation F1-score: 29.28%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.98%
# Average Validation Precision: 47.19%
# Average Validation Recall: 72.63%
# Average Validation F1-score: 56.18%
#
# Fold 9/10
# Found 25838 validated image filenames belonging to 7 classes.
# Found 2871 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 404/404 [==============================] - 752s 2s/step - loss: 1.8288 - accuracy: 0.2463 - precision_12: 0.0000e+00 - recall_12: 0.0000e+00 - val_loss: 1.8153 - val_accuracy: 0.2515 - val_precision_12: 0.0000e+00 - val_recall_12: 0.0000e+00
# Epoch 2/10
# 404/404 [==============================] - 729s 2s/step - loss: 1.8155 - accuracy: 0.2509 - precision_12: 0.0000e+00 - recall_12: 0.0000e+00 - val_loss: 1.8107 - val_accuracy: 0.2515 - val_precision_12: 0.0000e+00 - val_recall_12: 0.0000e+00
# Epoch 3/10
# 404/404 [==============================] - 733s 2s/step - loss: 1.7969 - accuracy: 0.2503 - precision_12: 0.0000e+00 - recall_12: 0.0000e+00 - val_loss: 1.7810 - val_accuracy: 0.2654 - val_precision_12: 0.0000e+00 - val_recall_12: 0.0000e+00
# Epoch 4/10
# 404/404 [==============================] - 756s 2s/step - loss: 1.7861 - accuracy: 0.2543 - precision_12: 0.0000e+00 - recall_12: 0.0000e+00 - val_loss: 1.7679 - val_accuracy: 0.2623 - val_precision_12: 0.0000e+00 - val_recall_12: 0.0000e+00
# Epoch 5/10
# 404/404 [==============================] - 788s 2s/step - loss: 1.7650 - accuracy: 0.2669 - precision_12: 1.0000 - recall_12: 3.8703e-05 - val_loss: 1.7130 - val_accuracy: 0.3180 - val_precision_12: 0.0000e+00 - val_recall_12: 0.0000e+00
# Epoch 6/10
# 404/404 [==============================] - 775s 2s/step - loss: 1.7125 - accuracy: 0.3035 - precision_12: 0.5893 - recall_12: 0.0137 - val_loss: 1.6159 - val_accuracy: 0.3790 - val_precision_12: 0.6684 - val_recall_12: 0.0449
# Epoch 7/10
# 404/404 [==============================] - 717s 2s/step - loss: 1.6631 - accuracy: 0.3348 - precision_12: 0.6101 - recall_12: 0.0589 - val_loss: 1.5597 - val_accuracy: 0.3957 - val_precision_12: 0.7017 - val_recall_12: 0.1442
# Epoch 8/10
# 404/404 [==============================] - 739s 2s/step - loss: 1.6169 - accuracy: 0.3620 - precision_12: 0.6449 - recall_12: 0.0988 - val_loss: 1.4887 - val_accuracy: 0.4215 - val_precision_12: 0.7512 - val_recall_12: 0.1661
# Epoch 9/10
# 404/404 [==============================] - 715s 2s/step - loss: 1.5576 - accuracy: 0.3938 - precision_12: 0.6947 - recall_12: 0.1312 - val_loss: 1.4146 - val_accuracy: 0.4549 - val_precision_12: 0.7676 - val_recall_12: 0.1978
# Epoch 10/10
# 404/404 [==============================] - 740s 2s/step - loss: 1.5080 - accuracy: 0.4174 - precision_12: 0.7266 - recall_12: 0.1599 - val_loss: 1.3611 - val_accuracy: 0.4817 - val_precision_12: 0.7604 - val_recall_12: 0.2365
# 45/45 [==============================] - 23s 395ms/step
# Metrics for Angry:
# Average Validation Accuracy: 82.07%
# Average Validation Precision: 35.06%
# Average Validation Recall: 30.61%
# Average Validation F1-score: 31.79%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.09%
# Average Validation Precision: 25.70%
# Average Validation Recall: 8.68%
# Average Validation F1-score: 12.40%
#
# Metrics for Happy:
# Average Validation Accuracy: 82.57%
# Average Validation Precision: 63.95%
# Average Validation Recall: 77.52%
# Average Validation F1-score: 69.26%
#
# Metrics for Sad:
# Average Validation Accuracy: 78.23%
# Average Validation Precision: 40.02%
# Average Validation Recall: 49.79%
# Average Validation F1-score: 43.81%
#
# Metrics for Surprise:
# Average Validation Accuracy: 79.83%
# Average Validation Precision: 36.60%
# Average Validation Recall: 26.29%
# Average Validation F1-score: 29.95%
#
# Metrics for Neutral:
# Average Validation Accuracy: 87.52%
# Average Validation Precision: 49.00%
# Average Validation Recall: 71.41%
# Average Validation F1-score: 56.88%
#
# Fold 10/10
# Found 25839 validated image filenames belonging to 7 classes.
# Found 2870 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 404/404 [==============================] - 810s 2s/step - loss: 1.8296 - accuracy: 0.2454 - precision_13: 0.0000e+00 - recall_13: 0.0000e+00 - val_loss: 1.8146 - val_accuracy: 0.2516 - val_precision_13: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 2/10
# 404/404 [==============================] - 726s 2s/step - loss: 1.8169 - accuracy: 0.2499 - precision_13: 0.0000e+00 - recall_13: 0.0000e+00 - val_loss: 1.8072 - val_accuracy: 0.2516 - val_precision_13: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 3/10
# 404/404 [==============================] - 763s 2s/step - loss: 1.7966 - accuracy: 0.2542 - precision_13: 0.0000e+00 - recall_13: 0.0000e+00 - val_loss: 1.7894 - val_accuracy: 0.2467 - val_precision_13: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 4/10
# 404/404 [==============================] - 752s 2s/step - loss: 1.7843 - accuracy: 0.2552 - precision_13: 0.0000e+00 - recall_13: 0.0000e+00 - val_loss: 1.7733 - val_accuracy: 0.2648 - val_precision_13: 0.0000e+00 - val_recall_13: 0.0000e+00
# Epoch 5/10
# 404/404 [==============================] - 758s 2s/step - loss: 1.7546 - accuracy: 0.2740 - precision_13: 0.5625 - recall_13: 6.9662e-04 - val_loss: 1.6986 - val_accuracy: 0.3056 - val_precision_13: 0.3000 - val_recall_13: 0.0010
# Epoch 6/10
# 404/404 [==============================] - 755s 2s/step - loss: 1.7039 - accuracy: 0.3126 - precision_13: 0.5868 - recall_13: 0.0224 - val_loss: 1.6089 - val_accuracy: 0.3655 - val_precision_13: 0.7122 - val_recall_13: 0.1000
# Epoch 7/10
# 404/404 [==============================] - 716s 2s/step - loss: 1.6550 - accuracy: 0.3417 - precision_13: 0.6129 - recall_13: 0.0686 - val_loss: 1.5746 - val_accuracy: 0.3798 - val_precision_13: 0.7468 - val_recall_13: 0.1223
# Epoch 8/10
# 404/404 [==============================] - 785s 2s/step - loss: 1.6108 - accuracy: 0.3625 - precision_13: 0.6757 - recall_13: 0.1029 - val_loss: 1.5317 - val_accuracy: 0.3997 - val_precision_13: 0.7060 - val_recall_13: 0.1648
# Epoch 9/10
# 404/404 [==============================] - 760s 2s/step - loss: 1.5585 - accuracy: 0.3904 - precision_13: 0.7014 - recall_13: 0.1314 - val_loss: 1.4430 - val_accuracy: 0.4484 - val_precision_13: 0.7179 - val_recall_13: 0.1986
# Epoch 10/10
# 404/404 [==============================] - 735s 2s/step - loss: 1.5075 - accuracy: 0.4130 - precision_13: 0.7232 - recall_13: 0.1589 - val_loss: 1.3775 - val_accuracy: 0.4742 - val_precision_13: 0.7756 - val_recall_13: 0.2167
# 45/45 [==============================] - 29s 535ms/step
# Metrics for Angry:
# Average Validation Accuracy: 82.19%
# Average Validation Precision: 35.29%
# Average Validation Recall: 30.64%
# Average Validation F1-score: 31.99%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.12%
# Average Validation Precision: 25.39%
# Average Validation Recall: 8.49%
# Average Validation F1-score: 12.21%
#
# Metrics for Happy:
# Average Validation Accuracy: 82.62%
# Average Validation Precision: 63.84%
# Average Validation Recall: 77.76%
# Average Validation F1-score: 69.37%
#
# Metrics for Sad:
# Average Validation Accuracy: 78.10%
# Average Validation Precision: 39.90%
# Average Validation Recall: 50.57%
# Average Validation F1-score: 44.06%
#
# Metrics for Surprise:
# Average Validation Accuracy: 79.71%
# Average Validation Precision: 36.43%
# Average Validation Recall: 26.77%
# Average Validation F1-score: 30.24%
#
# Metrics for Neutral:
# Average Validation Accuracy: 87.88%
# Average Validation Precision: 50.05%
# Average Validation Recall: 70.49%
# Average Validation F1-score: 57.27%
#
# Overall Average Metrics:
# Average Validation Accuracy: 84.59%
# Average Validation Precision: 35.84%
# Average Validation Recall: 37.82%
# Average Validation F1-score: 35.02%
# Confusion Matrix:
# [[1224    0  235  710  862  609  355]
#  [ 112    0   19   89  108   66   42]
#  [ 614    0  348  713  833  562 1027]
#  [ 306    0  172 5610  468  310  349]
#  [ 463    0  193  756 2511  630  412]
#  [ 767    0  300  808 1304 1293  358]
#  [  81    0  178  308  258  111 2235]]
