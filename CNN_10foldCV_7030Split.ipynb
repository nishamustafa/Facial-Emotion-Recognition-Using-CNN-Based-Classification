# %% [markdown]
# Import Libraries and Packages

# %%
import os
import shutil
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import opendatasets as od
import tensorflow as tf
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %% [markdown]
# Data Extraction

# %%
# Download the dataset
dataset_url = 'https://www.kaggle.com/datasets/msambare/fer2013'
od.download(dataset_url)

# Define dataset paths
train_path = "fer2013/train"
val_path = "fer2013/test"
# Out:
# Skipping, found downloaded files in ".\fer2013" (use force=True to force download)

# %% [markdown]
# Data Pre-Processing

# %%
# Initialize data generators with data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
val_datagen = ImageDataGenerator(rescale=1./255)

# Load training and validation data
batch_size = 64
target_size = (48, 48)
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=target_size,
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical',
    shuffle=True
)
val_generator = val_datagen.flow_from_directory(
    val_path,
    target_size=target_size,
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Define the number of classes
num_classes = 7

# New Model architecture with additional convolutional layers
model = Sequential([
        Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1)),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(512, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(1024, activation='relu'),
        Dropout(0.5),
        Dense(1024, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

# Model compilation
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 23, 23, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 21, 21, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 256)         295168
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 512)         1180160
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 3,131,911
# Trainable params: 3,131,911
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# CNN Algorithm

# %%
# Define the number of classes
num_classes = 7

def create_model():
    # New Model architecture with additional convolutional layers
    model = Sequential([
        Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1)),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(512, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(1024, activation='relu'),
        Dropout(0.5),
        Dense(1024, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    # Model compilation
    optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

    return model

# %% [markdown]
# K-Fold Cross Validation & Confusion Matrix

# %%
# Define emotion labels
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
num_classes = len(emotion_labels)

# Initialize dictionaries to store metrics for each emotion
accuracy_dict = {emotion: [] for emotion in emotion_labels}
precision_dict = {emotion: [] for emotion in emotion_labels}
recall_dict = {emotion: [] for emotion in emotion_labels}
f1_score_dict = {emotion: [] for emotion in emotion_labels}

# Get the list of filenames and corresponding classes
filenames = train_generator.filenames
classes = train_generator.classes

# Initialize lists to store true and predicted labels
true_labels_all = []
pred_labels_all = []

# Split the data into training (70%) and test (30%) sets
train_files, test_files, train_classes, test_classes = train_test_split(
    filenames, classes, test_size=0.3, stratify=classes, random_state=42
)

# Use Stratified K-Fold Cross Validation on the training data
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Loop through each fold
for fold, (train_indices, val_indices) in enumerate(skf.split(train_files, train_classes)):
    print(f"Fold {fold+1}/{skf.n_splits}")

    # Split data into training and validation sets for the current fold
    fold_train_files = [train_files[i] for i in train_indices]
    fold_train_classes = [train_classes[i] for i in train_indices]
    fold_val_files = [train_files[i] for i in val_indices]
    fold_val_classes = [train_classes[i] for i in val_indices]

    # Create dataframes for the current fold
    train_df = pd.DataFrame({'filename': fold_train_files, 'class': fold_train_classes}).astype(str)
    val_df = pd.DataFrame({'filename': fold_val_files, 'class': fold_val_classes}).astype(str)

    # Create model for each fold
    model = create_model()

    # Create data generators for the current fold
    train_generator_fold = train_datagen.flow_from_dataframe(
        train_df,
        directory=train_path,
        x_col='filename',
        y_col='class',
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical',
        shuffle=True
    )
    
    val_generator_fold = val_datagen.flow_from_dataframe(
        val_df,
        directory=train_path,
        x_col='filename',
        y_col='class',
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical',
        shuffle=False
    )

    # Train the model
    history = model.fit(
        train_generator_fold,
        epochs=10,
        validation_data=val_generator_fold,
        verbose=1
    )

    # Evaluate the model on validation set for each fold
    val_metrics = model.evaluate(
        val_generator_fold,
        verbose=0
    )
    val_loss, val_acc, val_precision, val_recall = val_metrics[0], val_metrics[1], val_metrics[2], val_metrics[3]
    
    # Calculate F1-score
    if val_precision + val_recall == 0:
        val_f1_score = 0
    else:
        val_f1_score = 2 * (val_precision * val_recall) / (val_precision + val_recall)

    # Generate confusion matrix for this fold
    y_pred = model.predict(val_generator_fold)
    y_true = val_generator_fold.classes
    conf_matrix = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

    # Append true and predicted labels
    true_labels_all.extend(y_true)
    pred_labels_all.extend(np.argmax(y_pred, axis=1))

    # Calculate metrics for each emotion
    for i, emotion in enumerate(emotion_labels):
        tp = conf_matrix[i, i]
        fp = np.sum(conf_matrix[:, i]) - tp
        fn = np.sum(conf_matrix[i, :]) - tp
        tn = np.sum(conf_matrix) - (tp + fp + fn)

        accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) > 0 else 0
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        accuracy_dict[emotion].append(accuracy)
        precision_dict[emotion].append(precision)
        recall_dict[emotion].append(recall)
        f1_score_dict[emotion].append(f1_score)

    # Print metrics for each emotion
    for emotion in emotion_labels:
        print(f"Metrics for {emotion}:")
        print(f"Average Validation Accuracy: {np.mean(accuracy_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation Precision: {np.mean(precision_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation Recall: {np.mean(recall_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation F1-score: {np.mean(f1_score_dict[emotion]) * 100:.2f}%")
        print()

# Print overall average metrics
print("Overall Average Metrics:")
print(f"Average Validation Accuracy: {np.mean([np.mean(accuracy_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation Precision: {np.mean([np.mean(precision_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation Recall: {np.mean([np.mean(recall_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation F1-score: {np.mean([np.mean(f1_score_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")

# Generate the confusion matrix using accumulated true and predicted labels
cm = confusion_matrix(true_labels_all, pred_labels_all, labels=np.arange(num_classes))

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='PuRd', xticklabels=emotion_labels, yticklabels=emotion_labels)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show()

# Print the confusion matrix
print("Confusion Matrix:")
print(cm)
# Out:
# Fold 1/10
# Found 18086 validated image filenames belonging to 7 classes.
# Found 2010 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 595s 2s/step - loss: 1.8313 - accuracy: 0.2436 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.8184 - val_accuracy: 0.2512 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 553s 2s/step - loss: 1.8215 - accuracy: 0.2505 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.8167 - val_accuracy: 0.2512 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 565s 2s/step - loss: 1.8173 - accuracy: 0.2502 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.8083 - val_accuracy: 0.2512 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 543s 2s/step - loss: 1.8076 - accuracy: 0.2509 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7964 - val_accuracy: 0.2498 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 565s 2s/step - loss: 1.7931 - accuracy: 0.2523 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7820 - val_accuracy: 0.2557 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 574s 2s/step - loss: 1.7877 - accuracy: 0.2512 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7731 - val_accuracy: 0.2562 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 552s 2s/step - loss: 1.7741 - accuracy: 0.2604 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7579 - val_accuracy: 0.2886 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 8/10
# 283/283 [==============================] - 539s 2s/step - loss: 1.7437 - accuracy: 0.2845 - precision_1: 0.4286 - recall_1: 9.9524e-04 - val_loss: 1.6822 - val_accuracy: 0.3214 - val_precision_1: 0.5000 - val_recall_1: 0.0030
# Epoch 9/10
# 283/283 [==============================] - 504s 2s/step - loss: 1.7156 - accuracy: 0.3018 - precision_1: 0.5075 - recall_1: 0.0112 - val_loss: 1.6560 - val_accuracy: 0.3100 - val_precision_1: 0.6491 - val_recall_1: 0.0736
# Epoch 10/10
# 283/283 [==============================] - 547s 2s/step - loss: 1.6823 - accuracy: 0.3276 - precision_1: 0.6058 - recall_1: 0.0402 - val_loss: 1.5893 - val_accuracy: 0.3726 - val_precision_1: 0.7010 - val_recall_1: 0.0711
# 32/32 [==============================] - 29s 521ms/step
# Metrics for Angry:
# Average Validation Accuracy: 85.17%
# Average Validation Precision: 30.43%
# Average Validation Recall: 5.00%
# Average Validation F1-score: 8.59%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.51%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.63%
# Average Validation Precision: 22.37%
# Average Validation Recall: 5.92%
# Average Validation F1-score: 9.37%
#
# Metrics for Happy:
# Average Validation Accuracy: 70.25%
# Average Validation Precision: 44.34%
# Average Validation Recall: 72.08%
# Average Validation F1-score: 54.90%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.65%
# Average Validation Precision: 35.24%
# Average Validation Recall: 21.33%
# Average Validation F1-score: 26.57%
#
# Metrics for Surprise:
# Average Validation Accuracy: 69.85%
# Average Validation Precision: 26.70%
# Average Validation Recall: 45.13%
# Average Validation F1-score: 33.55%
#
# Metrics for Neutral:
# Average Validation Accuracy: 87.46%
# Average Validation Precision: 44.72%
# Average Validation Recall: 57.21%
# Average Validation F1-score: 50.20%
#
# Fold 2/10
# Found 18086 validated image filenames belonging to 7 classes.
# Found 2010 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 594s 2s/step - loss: 1.8337 - accuracy: 0.2462 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8208 - val_accuracy: 0.2512 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 517s 2s/step - loss: 1.8198 - accuracy: 0.2485 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8133 - val_accuracy: 0.2512 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 562s 2s/step - loss: 1.8172 - accuracy: 0.2511 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8106 - val_accuracy: 0.2512 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 552s 2s/step - loss: 1.8093 - accuracy: 0.2515 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7911 - val_accuracy: 0.2512 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 524s 2s/step - loss: 1.7955 - accuracy: 0.2522 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7803 - val_accuracy: 0.2507 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 528s 2s/step - loss: 1.7903 - accuracy: 0.2528 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7795 - val_accuracy: 0.2502 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 530s 2s/step - loss: 1.7809 - accuracy: 0.2556 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7594 - val_accuracy: 0.2721 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 8/10
# 283/283 [==============================] - 569s 2s/step - loss: 1.7613 - accuracy: 0.2684 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7249 - val_accuracy: 0.2965 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 9/10
# 283/283 [==============================] - 574s 2s/step - loss: 1.7218 - accuracy: 0.2957 - precision_2: 0.5739 - recall_2: 0.0056 - val_loss: 1.6779 - val_accuracy: 0.3174 - val_precision_2: 0.5524 - val_recall_2: 0.0289
# Epoch 10/10
# 283/283 [==============================] - 534s 2s/step - loss: 1.6854 - accuracy: 0.3200 - precision_2: 0.6143 - recall_2: 0.0376 - val_loss: 1.5946 - val_accuracy: 0.3453 - val_precision_2: 0.6742 - val_recall_2: 0.1338
# 32/32 [==============================] - 16s 385ms/step
# Metrics for Angry:
# Average Validation Accuracy: 85.32%
# Average Validation Precision: 30.22%
# Average Validation Recall: 4.11%
# Average Validation F1-score: 7.20%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 82.94%
# Average Validation Precision: 19.28%
# Average Validation Recall: 5.93%
# Average Validation F1-score: 9.03%
#
# Metrics for Happy:
# Average Validation Accuracy: 64.25%
# Average Validation Precision: 40.19%
# Average Validation Recall: 78.71%
# Average Validation F1-score: 52.79%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.28%
# Average Validation Precision: 30.59%
# Average Validation Recall: 16.55%
# Average Validation F1-score: 21.39%
#
# Metrics for Surprise:
# Average Validation Accuracy: 74.75%
# Average Validation Precision: 28.65%
# Average Validation Recall: 30.85%
# Average Validation F1-score: 27.52%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.77%
# Average Validation Precision: 43.07%
# Average Validation Recall: 60.14%
# Average Validation F1-score: 50.10%
#
# Fold 3/10
# Found 18086 validated image filenames belonging to 7 classes.
# Found 2010 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 587s 2s/step - loss: 1.8328 - accuracy: 0.2427 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8172 - val_accuracy: 0.2512 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 505s 2s/step - loss: 1.8197 - accuracy: 0.2491 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8134 - val_accuracy: 0.2512 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 522s 2s/step - loss: 1.8165 - accuracy: 0.2504 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8056 - val_accuracy: 0.2512 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 498s 2s/step - loss: 1.8012 - accuracy: 0.2525 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7929 - val_accuracy: 0.2552 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 517s 2s/step - loss: 1.7920 - accuracy: 0.2528 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7833 - val_accuracy: 0.2577 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 515s 2s/step - loss: 1.7846 - accuracy: 0.2545 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7731 - val_accuracy: 0.2607 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 536s 2s/step - loss: 1.7703 - accuracy: 0.2622 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7386 - val_accuracy: 0.2925 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 8/10
# 283/283 [==============================] - 539s 2s/step - loss: 1.7397 - accuracy: 0.2813 - precision_3: 0.4444 - recall_3: 0.0013 - val_loss: 1.7062 - val_accuracy: 0.3119 - val_precision_3: 0.6471 - val_recall_3: 0.0219
# Epoch 9/10
# 283/283 [==============================] - 502s 2s/step - loss: 1.7143 - accuracy: 0.2996 - precision_3: 0.5836 - recall_3: 0.0114 - val_loss: 1.6433 - val_accuracy: 0.3522 - val_precision_3: 0.6404 - val_recall_3: 0.0567
# Epoch 10/10
# 283/283 [==============================] - 522s 2s/step - loss: 1.6806 - accuracy: 0.3251 - precision_3: 0.5765 - recall_3: 0.0360 - val_loss: 1.5992 - val_accuracy: 0.3796 - val_precision_3: 0.7000 - val_recall_3: 0.0975
# 32/32 [==============================] - 20s 512ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.20%
# Average Validation Precision: 29.33%
# Average Validation Recall: 8.81%
# Average Validation F1-score: 12.11%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 82.59%
# Average Validation Precision: 18.50%
# Average Validation Recall: 6.29%
# Average Validation F1-score: 9.32%
#
# Metrics for Happy:
# Average Validation Accuracy: 65.84%
# Average Validation Precision: 41.36%
# Average Validation Recall: 79.54%
# Average Validation F1-score: 54.13%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.20%
# Average Validation Precision: 31.66%
# Average Validation Recall: 18.32%
# Average Validation F1-score: 23.10%
#
# Metrics for Surprise:
# Average Validation Accuracy: 76.57%
# Average Validation Precision: 29.44%
# Average Validation Recall: 25.40%
# Average Validation F1-score: 24.94%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.30%
# Average Validation Precision: 42.27%
# Average Validation Recall: 63.66%
# Average Validation F1-score: 50.61%
#
# Fold 4/10
# Found 18086 validated image filenames belonging to 7 classes.
# Found 2010 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 573s 2s/step - loss: 1.8313 - accuracy: 0.2446 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8173 - val_accuracy: 0.2512 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 520s 2s/step - loss: 1.8200 - accuracy: 0.2501 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8152 - val_accuracy: 0.2512 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 535s 2s/step - loss: 1.8154 - accuracy: 0.2511 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8061 - val_accuracy: 0.2512 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 499s 2s/step - loss: 1.7995 - accuracy: 0.2534 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7815 - val_accuracy: 0.2502 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 491s 2s/step - loss: 1.7914 - accuracy: 0.2551 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7715 - val_accuracy: 0.2498 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 529s 2s/step - loss: 1.7820 - accuracy: 0.2554 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7573 - val_accuracy: 0.2582 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 491s 2s/step - loss: 1.7606 - accuracy: 0.2680 - precision_4: 0.6667 - recall_4: 1.1058e-04 - val_loss: 1.7099 - val_accuracy: 0.3144 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 8/10
# 283/283 [==============================] - 535s 2s/step - loss: 1.7317 - accuracy: 0.2932 - precision_4: 0.4922 - recall_4: 0.0035 - val_loss: 1.6639 - val_accuracy: 0.3169 - val_precision_4: 0.6829 - val_recall_4: 0.0279
# Epoch 9/10
# 283/283 [==============================] - 531s 2s/step - loss: 1.6922 - accuracy: 0.3205 - precision_4: 0.5863 - recall_4: 0.0274 - val_loss: 1.6126 - val_accuracy: 0.3612 - val_precision_4: 0.6727 - val_recall_4: 0.0930
# Epoch 10/10
# 283/283 [==============================] - 537s 2s/step - loss: 1.6562 - accuracy: 0.3395 - precision_4: 0.6254 - recall_4: 0.0631 - val_loss: 1.5490 - val_accuracy: 0.3876 - val_precision_4: 0.7139 - val_recall_4: 0.1229
# 32/32 [==============================] - 18s 407ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.37%
# Average Validation Precision: 31.52%
# Average Validation Recall: 10.19%
# Average Validation F1-score: 14.29%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.02%
# Average Validation Precision: 19.09%
# Average Validation Recall: 5.59%
# Average Validation F1-score: 8.48%
#
# Metrics for Happy:
# Average Validation Accuracy: 67.65%
# Average Validation Precision: 42.93%
# Average Validation Recall: 77.77%
# Average Validation F1-score: 54.98%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.12%
# Average Validation Precision: 32.11%
# Average Validation Recall: 19.34%
# Average Validation F1-score: 24.04%
#
# Metrics for Surprise:
# Average Validation Accuracy: 75.19%
# Average Validation Precision: 28.78%
# Average Validation Recall: 29.48%
# Average Validation F1-score: 26.86%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.44%
# Average Validation Precision: 42.61%
# Average Validation Recall: 63.96%
# Average Validation F1-score: 51.00%
#
# Fold 5/10
# Found 18086 validated image filenames belonging to 7 classes.
# Found 2010 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 589s 2s/step - loss: 1.8358 - accuracy: 0.2454 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8147 - val_accuracy: 0.2512 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 555s 2s/step - loss: 1.8209 - accuracy: 0.2499 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8108 - val_accuracy: 0.2512 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 543s 2s/step - loss: 1.8145 - accuracy: 0.2504 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8022 - val_accuracy: 0.2512 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 487s 2s/step - loss: 1.7982 - accuracy: 0.2530 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7920 - val_accuracy: 0.2627 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 514s 2s/step - loss: 1.7904 - accuracy: 0.2509 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7833 - val_accuracy: 0.2592 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 525s 2s/step - loss: 1.7755 - accuracy: 0.2573 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7519 - val_accuracy: 0.2821 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 487s 2s/step - loss: 1.7473 - accuracy: 0.2827 - precision_5: 0.4815 - recall_5: 7.1879e-04 - val_loss: 1.7176 - val_accuracy: 0.3090 - val_precision_5: 0.3571 - val_recall_5: 0.0025
# Epoch 8/10
# 283/283 [==============================] - 521s 2s/step - loss: 1.7203 - accuracy: 0.2979 - precision_5: 0.5168 - recall_5: 0.0085 - val_loss: 1.6610 - val_accuracy: 0.3244 - val_precision_5: 0.6237 - val_recall_5: 0.0602
# Epoch 9/10
# 283/283 [==============================] - 519s 2s/step - loss: 1.6843 - accuracy: 0.3224 - precision_5: 0.6004 - recall_5: 0.0369 - val_loss: 1.6044 - val_accuracy: 0.3716 - val_precision_5: 0.7684 - val_recall_5: 0.0726
# Epoch 10/10
# 283/283 [==============================] - 531s 2s/step - loss: 1.6573 - accuracy: 0.3356 - precision_5: 0.6263 - recall_5: 0.0675 - val_loss: 1.5872 - val_accuracy: 0.3627 - val_precision_5: 0.6734 - val_recall_5: 0.1836
# 32/32 [==============================] - 17s 407ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.56%
# Average Validation Precision: 32.46%
# Average Validation Recall: 9.66%
# Average Validation F1-score: 13.93%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.30%
# Average Validation Precision: 18.43%
# Average Validation Recall: 4.89%
# Average Validation F1-score: 7.53%
#
# Metrics for Happy:
# Average Validation Accuracy: 65.82%
# Average Validation Precision: 41.70%
# Average Validation Recall: 80.28%
# Average Validation F1-score: 54.43%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.19%
# Average Validation Precision: 31.69%
# Average Validation Recall: 18.23%
# Average Validation F1-score: 23.01%
#
# Metrics for Surprise:
# Average Validation Accuracy: 75.76%
# Average Validation Precision: 28.75%
# Average Validation Recall: 27.67%
# Average Validation F1-score: 26.26%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.81%
# Average Validation Precision: 43.57%
# Average Validation Recall: 62.79%
# Average Validation F1-score: 51.25%
#
# Fold 6/10
# Found 18086 validated image filenames belonging to 7 classes.
# Found 2010 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 593s 2s/step - loss: 1.8344 - accuracy: 0.2428 - precision_6: 0.5000 - recall_6: 5.5291e-05 - val_loss: 1.8160 - val_accuracy: 0.2512 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 522s 2s/step - loss: 1.8219 - accuracy: 0.2492 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8122 - val_accuracy: 0.2512 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 510s 2s/step - loss: 1.8156 - accuracy: 0.2512 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8058 - val_accuracy: 0.2512 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 530s 2s/step - loss: 1.8022 - accuracy: 0.2502 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7955 - val_accuracy: 0.2383 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 531s 2s/step - loss: 1.7911 - accuracy: 0.2539 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7794 - val_accuracy: 0.2602 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 516s 2s/step - loss: 1.7860 - accuracy: 0.2524 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7829 - val_accuracy: 0.2662 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 526s 2s/step - loss: 1.7712 - accuracy: 0.2630 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7246 - val_accuracy: 0.2925 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 8/10
# 283/283 [==============================] - 495s 2s/step - loss: 1.7361 - accuracy: 0.2862 - precision_6: 0.5412 - recall_6: 0.0025 - val_loss: 1.6749 - val_accuracy: 0.3114 - val_precision_6: 0.5839 - val_recall_6: 0.0398
# Epoch 9/10
# 283/283 [==============================] - 529s 2s/step - loss: 1.7080 - accuracy: 0.3045 - precision_6: 0.5286 - recall_6: 0.0174 - val_loss: 1.6418 - val_accuracy: 0.3547 - val_precision_6: 0.6855 - val_recall_6: 0.0423
# Epoch 10/10
# 283/283 [==============================] - 540s 2s/step - loss: 1.6689 - accuracy: 0.3314 - precision_6: 0.6153 - recall_6: 0.0556 - val_loss: 1.5699 - val_accuracy: 0.3706 - val_precision_6: 0.7062 - val_recall_6: 0.1303
# 32/32 [==============================] - 23s 590ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.92%
# Average Validation Precision: 31.18%
# Average Validation Recall: 11.21%
# Average Validation F1-score: 15.19%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.62%
# Average Validation Precision: 21.08%
# Average Validation Recall: 4.71%
# Average Validation F1-score: 7.42%
#
# Metrics for Happy:
# Average Validation Accuracy: 65.78%
# Average Validation Precision: 41.57%
# Average Validation Recall: 80.83%
# Average Validation F1-score: 54.51%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.27%
# Average Validation Precision: 31.03%
# Average Validation Recall: 17.01%
# Average Validation F1-score: 21.79%
#
# Metrics for Surprise:
# Average Validation Accuracy: 76.08%
# Average Validation Precision: 28.64%
# Average Validation Recall: 26.56%
# Average Validation F1-score: 25.88%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.81%
# Average Validation Precision: 43.60%
# Average Validation Recall: 63.59%
# Average Validation F1-score: 51.56%
#
# Fold 7/10
# Found 18087 validated image filenames belonging to 7 classes.
# Found 2009 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 564s 2s/step - loss: 1.8310 - accuracy: 0.2432 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8163 - val_accuracy: 0.2514 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 525s 2s/step - loss: 1.8205 - accuracy: 0.2490 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8104 - val_accuracy: 0.2514 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 413s 1s/step - loss: 1.8108 - accuracy: 0.2503 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7975 - val_accuracy: 0.2544 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 411s 1s/step - loss: 1.7960 - accuracy: 0.2505 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7878 - val_accuracy: 0.2613 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 381s 1s/step - loss: 1.7889 - accuracy: 0.2524 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7748 - val_accuracy: 0.2598 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 400s 1s/step - loss: 1.7758 - accuracy: 0.2575 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7493 - val_accuracy: 0.2743 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 412s 1s/step - loss: 1.7475 - accuracy: 0.2768 - precision_7: 0.5366 - recall_7: 0.0012 - val_loss: 1.6986 - val_accuracy: 0.3121 - val_precision_7: 0.4800 - val_recall_7: 0.0060
# Epoch 8/10
# 283/283 [==============================] - 425s 1s/step - loss: 1.7201 - accuracy: 0.2935 - precision_7: 0.5245 - recall_7: 0.0083 - val_loss: 1.6679 - val_accuracy: 0.3474 - val_precision_7: 0.6286 - val_recall_7: 0.0110
# Epoch 9/10
# 283/283 [==============================] - 413s 1s/step - loss: 1.6844 - accuracy: 0.3224 - precision_7: 0.6043 - recall_7: 0.0323 - val_loss: 1.5988 - val_accuracy: 0.3584 - val_precision_7: 0.6899 - val_recall_7: 0.1229
# Epoch 10/10
# 283/283 [==============================] - 419s 1s/step - loss: 1.6497 - accuracy: 0.3440 - precision_7: 0.6338 - recall_7: 0.0690 - val_loss: 1.5424 - val_accuracy: 0.4017 - val_precision_7: 0.7007 - val_recall_7: 0.1573
# 32/32 [==============================] - 18s 447ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.87%
# Average Validation Precision: 31.66%
# Average Validation Recall: 12.47%
# Average Validation F1-score: 16.64%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.76%
# Average Validation Precision: 21.39%
# Average Validation Recall: 4.54%
# Average Validation F1-score: 7.23%
#
# Metrics for Happy:
# Average Validation Accuracy: 66.33%
# Average Validation Precision: 41.97%
# Average Validation Recall: 80.99%
# Average Validation F1-score: 54.95%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.28%
# Average Validation Precision: 31.87%
# Average Validation Recall: 18.53%
# Average Validation F1-score: 23.19%
#
# Metrics for Surprise:
# Average Validation Accuracy: 76.67%
# Average Validation Precision: 29.67%
# Average Validation Recall: 25.93%
# Average Validation F1-score: 26.10%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.47%
# Average Validation Precision: 42.92%
# Average Validation Recall: 64.54%
# Average Validation F1-score: 51.33%
#
# Fold 8/10
# Found 18087 validated image filenames belonging to 7 classes.
# Found 2009 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 457s 2s/step - loss: 1.8303 - accuracy: 0.2459 - precision_8: 1.0000 - recall_8: 5.5288e-05 - val_loss: 1.8148 - val_accuracy: 0.2514 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 391s 1s/step - loss: 1.8202 - accuracy: 0.2487 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8137 - val_accuracy: 0.2514 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 292s 1s/step - loss: 1.8160 - accuracy: 0.2510 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8086 - val_accuracy: 0.2514 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 297s 1s/step - loss: 1.8049 - accuracy: 0.2513 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7858 - val_accuracy: 0.2563 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 296s 1s/step - loss: 1.7941 - accuracy: 0.2524 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7856 - val_accuracy: 0.2558 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 297s 1s/step - loss: 1.7873 - accuracy: 0.2543 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7723 - val_accuracy: 0.2593 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 270s 951ms/step - loss: 1.7750 - accuracy: 0.2600 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7399 - val_accuracy: 0.2937 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 8/10
# 283/283 [==============================] - 277s 976ms/step - loss: 1.7408 - accuracy: 0.2920 - precision_8: 0.5422 - recall_8: 0.0025 - val_loss: 1.6702 - val_accuracy: 0.3216 - val_precision_8: 0.6721 - val_recall_8: 0.0408
# Epoch 9/10
# 283/283 [==============================] - 295s 1s/step - loss: 1.6999 - accuracy: 0.3140 - precision_8: 0.5816 - recall_8: 0.0294 - val_loss: 1.6077 - val_accuracy: 0.3589 - val_precision_8: 0.7053 - val_recall_8: 0.1060
# Epoch 10/10
# 283/283 [==============================] - 300s 1s/step - loss: 1.6592 - accuracy: 0.3348 - precision_8: 0.6411 - recall_8: 0.0711 - val_loss: 1.6084 - val_accuracy: 0.3664 - val_precision_8: 0.6840 - val_recall_8: 0.0916
# 32/32 [==============================] - 9s 235ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.10%
# Average Validation Precision: 31.45%
# Average Validation Recall: 11.18%
# Average Validation F1-score: 15.06%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.38%
# Average Validation Precision: 21.54%
# Average Validation Recall: 5.75%
# Average Validation F1-score: 8.51%
#
# Metrics for Happy:
# Average Validation Accuracy: 67.96%
# Average Validation Precision: 44.09%
# Average Validation Recall: 78.24%
# Average Validation F1-score: 55.45%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.26%
# Average Validation Precision: 32.09%
# Average Validation Recall: 18.88%
# Average Validation F1-score: 23.56%
#
# Metrics for Surprise:
# Average Validation Accuracy: 75.97%
# Average Validation Precision: 29.44%
# Average Validation Recall: 28.35%
# Average Validation F1-score: 27.15%
#
# Metrics for Neutral:
# Average Validation Accuracy: 85.52%
# Average Validation Precision: 41.41%
# Average Validation Recall: 65.71%
# Average Validation F1-score: 50.36%
#
# Fold 9/10
# Found 18087 validated image filenames belonging to 7 classes.
# Found 2009 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 310s 1s/step - loss: 1.8332 - accuracy: 0.2437 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8183 - val_accuracy: 0.2514 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 283s 998ms/step - loss: 1.8205 - accuracy: 0.2501 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8131 - val_accuracy: 0.2514 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 296s 1s/step - loss: 1.8163 - accuracy: 0.2505 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8110 - val_accuracy: 0.2514 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 276s 973ms/step - loss: 1.8073 - accuracy: 0.2513 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7930 - val_accuracy: 0.2514 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 280s 986ms/step - loss: 1.7939 - accuracy: 0.2522 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7871 - val_accuracy: 0.2554 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 291s 1s/step - loss: 1.7889 - accuracy: 0.2507 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7746 - val_accuracy: 0.2549 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 191s 676ms/step - loss: 1.7779 - accuracy: 0.2549 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7507 - val_accuracy: 0.2648 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 8/10
# 283/283 [==============================] - 198s 701ms/step - loss: 1.7505 - accuracy: 0.2782 - precision_9: 0.4615 - recall_9: 6.6346e-04 - val_loss: 1.7335 - val_accuracy: 0.2947 - val_precision_9: 0.5556 - val_recall_9: 0.0050
# Epoch 9/10
# 283/283 [==============================] - 194s 683ms/step - loss: 1.7073 - accuracy: 0.3105 - precision_9: 0.5704 - recall_9: 0.0175 - val_loss: 1.6485 - val_accuracy: 0.3375 - val_precision_9: 0.6382 - val_recall_9: 0.1115
# Epoch 10/10
# 283/283 [==============================] - 155s 545ms/step - loss: 1.6721 - accuracy: 0.3303 - precision_9: 0.5905 - recall_9: 0.0525 - val_loss: 1.6398 - val_accuracy: 0.3509 - val_precision_9: 0.6171 - val_recall_9: 0.1220
# 32/32 [==============================] - 6s 154ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.08%
# Average Validation Precision: 30.57%
# Average Validation Recall: 10.69%
# Average Validation F1-score: 14.55%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.42%
# Average Validation Precision: 21.77%
# Average Validation Recall: 5.81%
# Average Validation F1-score: 8.66%
#
# Metrics for Happy:
# Average Validation Accuracy: 68.47%
# Average Validation Precision: 44.42%
# Average Validation Recall: 77.69%
# Average Validation F1-score: 55.66%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.26%
# Average Validation Precision: 31.32%
# Average Validation Recall: 17.94%
# Average Validation F1-score: 22.57%
#
# Metrics for Surprise:
# Average Validation Accuracy: 76.29%
# Average Validation Precision: 29.78%
# Average Validation Recall: 27.83%
# Average Validation F1-score: 27.18%
#
# Metrics for Neutral:
# Average Validation Accuracy: 84.17%
# Average Validation Precision: 39.80%
# Average Validation Recall: 67.52%
# Average Validation F1-score: 49.27%
#
# Fold 10/10
# Found 18087 validated image filenames belonging to 7 classes.
# Found 2009 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 199s 679ms/step - loss: 1.8359 - accuracy: 0.2476 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8154 - val_accuracy: 0.2514 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 179s 632ms/step - loss: 1.8204 - accuracy: 0.2502 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8135 - val_accuracy: 0.2514 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 188s 664ms/step - loss: 1.8165 - accuracy: 0.2513 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8104 - val_accuracy: 0.2514 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 187s 662ms/step - loss: 1.8116 - accuracy: 0.2515 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7973 - val_accuracy: 0.2578 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 191s 673ms/step - loss: 1.7972 - accuracy: 0.2511 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7799 - val_accuracy: 0.2613 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 190s 672ms/step - loss: 1.7888 - accuracy: 0.2545 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7712 - val_accuracy: 0.2539 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 191s 673ms/step - loss: 1.7824 - accuracy: 0.2521 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7525 - val_accuracy: 0.2827 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 8/10
# 283/283 [==============================] - 191s 674ms/step - loss: 1.7609 - accuracy: 0.2682 - precision_10: 0.2500 - recall_10: 5.5288e-05 - val_loss: 1.7034 - val_accuracy: 0.3051 - val_precision_10: 1.0000 - val_recall_10: 0.0015
# Epoch 9/10
# 283/283 [==============================] - 190s 670ms/step - loss: 1.7283 - accuracy: 0.2901 - precision_10: 0.4569 - recall_10: 0.0029 - val_loss: 1.6613 - val_accuracy: 0.3529 - val_precision_10: 0.6271 - val_recall_10: 0.0184
# Epoch 10/10
# 283/283 [==============================] - 192s 677ms/step - loss: 1.6936 - accuracy: 0.3143 - precision_10: 0.6074 - recall_10: 0.0253 - val_loss: 1.6047 - val_accuracy: 0.3644 - val_precision_10: 0.6499 - val_recall_10: 0.1414
# 32/32 [==============================] - 6s 157ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.19%
# Average Validation Precision: 31.38%
# Average Validation Recall: 10.73%
# Average Validation F1-score: 14.82%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.55%
# Average Validation Precision: 22.39%
# Average Validation Recall: 5.65%
# Average Validation F1-score: 8.53%
#
# Metrics for Happy:
# Average Validation Accuracy: 67.23%
# Average Validation Precision: 43.47%
# Average Validation Recall: 78.57%
# Average Validation F1-score: 55.07%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.33%
# Average Validation Precision: 31.65%
# Average Validation Recall: 17.93%
# Average Validation F1-score: 22.67%
#
# Metrics for Surprise:
# Average Validation Accuracy: 76.81%
# Average Validation Precision: 30.40%
# Average Validation Recall: 26.38%
# Average Validation F1-score: 26.40%
#
# Metrics for Neutral:
# Average Validation Accuracy: 84.44%
# Average Validation Precision: 40.20%
# Average Validation Recall: 67.30%
# Average Validation F1-score: 49.58%
#
# Overall Average Metrics:
# Average Validation Accuracy: 82.00%
# Average Validation Precision: 28.50%
# Average Validation Recall: 29.51%
# Average Validation F1-score: 25.30%
# Confusion Matrix:
# [[ 300    0  143 1087  281  590  396]
#  [  17    0   20  125   52   54   37]
#  [ 161    0  162 1039  244  450  812]
#  [ 121    0   87 3968  232  293  349]
#  [ 136    0  126 1536  623  660  394]
#  [ 210    0  149 1314  404  892  412]
#  [  36    0   74  402   89  125 1494]]
