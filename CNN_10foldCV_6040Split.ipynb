# %% [markdown]
# Import Libraries and Packages

# %%
import os
import shutil
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import opendatasets as od
import tensorflow as tf
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %% [markdown]
# Data Extraction

# %%
# Download the dataset
dataset_url = 'https://www.kaggle.com/datasets/msambare/fer2013'
od.download(dataset_url)

# Define dataset paths
train_path = "fer2013/train"
val_path = "fer2013/test"
# Out:
# Skipping, found downloaded files in ".\fer2013" (use force=True to force download)

# %% [markdown]
# Data Pre-Processing

# %%
# Initialize data generators with data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
val_datagen = ImageDataGenerator(rescale=1./255)

# Load training and validation data
batch_size = 64
target_size = (48, 48)
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=target_size,
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical',
    shuffle=True
)
val_generator = val_datagen.flow_from_directory(
    val_path,
    target_size=target_size,
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Define the number of classes
num_classes = 7

# New Model architecture with additional convolutional layers
model = Sequential([
        Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1)),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(512, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(1024, activation='relu'),
        Dropout(0.5),
        Dense(1024, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

# Model compilation
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 23, 23, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 21, 21, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 256)         295168
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 512)         1180160
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 3,131,911
# Trainable params: 3,131,911
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# CNN Algorithm

# %%
# Define the number of classes
num_classes = 7

def create_model():
    # New Model architecture with additional convolutional layers
    model = Sequential([
        Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1)),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(512, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(1024, activation='relu'),
        Dropout(0.5),
        Dense(1024, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    # Model compilation
    optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

    return model

# %% [markdown]
# K-Fold Cross Validation & Confusion Matrix

# %%
# Define emotion labels
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
num_classes = len(emotion_labels)

# Initialize dictionaries to store metrics for each emotion
accuracy_dict = {emotion: [] for emotion in emotion_labels}
precision_dict = {emotion: [] for emotion in emotion_labels}
recall_dict = {emotion: [] for emotion in emotion_labels}
f1_score_dict = {emotion: [] for emotion in emotion_labels}

# Get the list of filenames and corresponding classes
filenames = train_generator.filenames
classes = train_generator.classes

# Initialize lists to store true and predicted labels
true_labels_all = []
pred_labels_all = []

# Split the data into training (60%) and test (40%) sets
train_files, test_files, train_classes, test_classes = train_test_split(
    filenames, classes, test_size=0.4, stratify=classes, random_state=42
)

# Use Stratified K-Fold Cross Validation on the training data
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Loop through each fold
for fold, (train_indices, val_indices) in enumerate(skf.split(train_files, train_classes)):
    print(f"Fold {fold+1}/{skf.n_splits}")

    # Split data into training and validation sets for the current fold
    fold_train_files = [train_files[i] for i in train_indices]
    fold_train_classes = [train_classes[i] for i in train_indices]
    fold_val_files = [train_files[i] for i in val_indices]
    fold_val_classes = [train_classes[i] for i in val_indices]

    # Create dataframes for the current fold
    train_df = pd.DataFrame({'filename': fold_train_files, 'class': fold_train_classes}).astype(str)
    val_df = pd.DataFrame({'filename': fold_val_files, 'class': fold_val_classes}).astype(str)

    # Create model for each fold
    model = create_model()

    # Create data generators for the current fold
    train_generator_fold = train_datagen.flow_from_dataframe(
        train_df,
        directory=train_path,
        x_col='filename',
        y_col='class',
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical',
        shuffle=True
    )
    
    val_generator_fold = val_datagen.flow_from_dataframe(
        val_df,
        directory=train_path,
        x_col='filename',
        y_col='class',
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical',
        shuffle=False
    )

    # Train the model
    history = model.fit(
        train_generator_fold,
        epochs=10,
        validation_data=val_generator_fold,
        verbose=1
    )

    # Evaluate the model on validation set for each fold
    val_metrics = model.evaluate(
        val_generator_fold,
        verbose=0
    )
    val_loss, val_acc, val_precision, val_recall = val_metrics[0], val_metrics[1], val_metrics[2], val_metrics[3]
    
    # Calculate F1-score
    if val_precision + val_recall == 0:
        val_f1_score = 0
    else:
        val_f1_score = 2 * (val_precision * val_recall) / (val_precision + val_recall)

    # Generate confusion matrix for this fold
    y_pred = model.predict(val_generator_fold)
    y_true = val_generator_fold.classes
    conf_matrix = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

    # Append true and predicted labels
    true_labels_all.extend(y_true)
    pred_labels_all.extend(np.argmax(y_pred, axis=1))

    # Calculate metrics for each emotion
    for i, emotion in enumerate(emotion_labels):
        tp = conf_matrix[i, i]
        fp = np.sum(conf_matrix[:, i]) - tp
        fn = np.sum(conf_matrix[i, :]) - tp
        tn = np.sum(conf_matrix) - (tp + fp + fn)

        accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) > 0 else 0
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        accuracy_dict[emotion].append(accuracy)
        precision_dict[emotion].append(precision)
        recall_dict[emotion].append(recall)
        f1_score_dict[emotion].append(f1_score)

    # Print metrics for each emotion
    for emotion in emotion_labels:
        print(f"Metrics for {emotion}:")
        print(f"Average Validation Accuracy: {np.mean(accuracy_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation Precision: {np.mean(precision_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation Recall: {np.mean(recall_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation F1-score: {np.mean(f1_score_dict[emotion]) * 100:.2f}%")
        print()

# Print overall average metrics
print("Overall Average Metrics:")
print(f"Average Validation Accuracy: {np.mean([np.mean(accuracy_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation Precision: {np.mean([np.mean(precision_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation Recall: {np.mean([np.mean(recall_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation F1-score: {np.mean([np.mean(f1_score_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")

# Generate the confusion matrix using accumulated true and predicted labels
cm = confusion_matrix(true_labels_all, pred_labels_all, labels=np.arange(num_classes))

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='PuRd', xticklabels=emotion_labels, yticklabels=emotion_labels)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show()

# Print the confusion matrix
print("Confusion Matrix:")
print(cm)
# Out:
# Fold 1/10
# Found 15502 validated image filenames belonging to 7 classes.
# Found 1723 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 493s 2s/step - loss: 1.8337 - accuracy: 0.2396 - precision_1: 0.5000 - recall_1: 6.4508e-05 - val_loss: 1.8179 - val_accuracy: 0.2513 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 468s 2s/step - loss: 1.8226 - accuracy: 0.2496 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.8155 - val_accuracy: 0.2513 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 485s 2s/step - loss: 1.8162 - accuracy: 0.2513 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.8095 - val_accuracy: 0.2513 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 494s 2s/step - loss: 1.8026 - accuracy: 0.2507 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7924 - val_accuracy: 0.2519 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 477s 2s/step - loss: 1.7953 - accuracy: 0.2538 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7858 - val_accuracy: 0.2571 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 474s 2s/step - loss: 1.7887 - accuracy: 0.2539 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7874 - val_accuracy: 0.2571 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 515s 2s/step - loss: 1.7823 - accuracy: 0.2548 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7752 - val_accuracy: 0.2757 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 490s 2s/step - loss: 1.7652 - accuracy: 0.2698 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7305 - val_accuracy: 0.2780 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 459s 2s/step - loss: 1.7372 - accuracy: 0.2859 - precision_1: 0.5294 - recall_1: 0.0023 - val_loss: 1.6811 - val_accuracy: 0.3355 - val_precision_1: 0.4528 - val_recall_1: 0.0139
# Epoch 10/10
# 243/243 [==============================] - 444s 2s/step - loss: 1.7050 - accuracy: 0.3100 - precision_1: 0.5935 - recall_1: 0.0178 - val_loss: 1.6519 - val_accuracy: 0.3279 - val_precision_1: 0.6347 - val_recall_1: 0.0807
# 27/27 [==============================] - 24s 468ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.79%
# Average Validation Precision: 36.90%
# Average Validation Recall: 12.92%
# Average Validation F1-score: 19.14%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.49%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 84.79%
# Average Validation Precision: 28.95%
# Average Validation Recall: 4.47%
# Average Validation F1-score: 7.75%
#
# Metrics for Happy:
# Average Validation Accuracy: 45.79%
# Average Validation Precision: 30.66%
# Average Validation Recall: 91.69%
# Average Validation F1-score: 45.95%
#
# Metrics for Sad:
# Average Validation Accuracy: 81.78%
# Average Validation Precision: 30.95%
# Average Validation Recall: 4.36%
# Average Validation F1-score: 7.65%
#
# Metrics for Surprise:
# Average Validation Accuracy: 81.20%
# Average Validation Precision: 33.00%
# Average Validation Recall: 11.38%
# Average Validation F1-score: 16.92%
#
# Metrics for Neutral:
# Average Validation Accuracy: 88.74%
# Average Validation Precision: 48.78%
# Average Validation Recall: 42.11%
# Average Validation F1-score: 45.20%
#
# Fold 2/10
# Found 15502 validated image filenames belonging to 7 classes.
# Found 1723 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 508s 2s/step - loss: 1.8342 - accuracy: 0.2437 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8138 - val_accuracy: 0.2513 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 455s 2s/step - loss: 1.8219 - accuracy: 0.2489 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8127 - val_accuracy: 0.2513 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 458s 2s/step - loss: 1.8192 - accuracy: 0.2509 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8098 - val_accuracy: 0.2513 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 442s 2s/step - loss: 1.8124 - accuracy: 0.2518 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7979 - val_accuracy: 0.2519 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 487s 2s/step - loss: 1.7985 - accuracy: 0.2524 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7838 - val_accuracy: 0.2571 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 473s 2s/step - loss: 1.7936 - accuracy: 0.2515 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7795 - val_accuracy: 0.2548 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 452s 2s/step - loss: 1.7876 - accuracy: 0.2538 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7910 - val_accuracy: 0.2339 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 450s 2s/step - loss: 1.7778 - accuracy: 0.2568 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7451 - val_accuracy: 0.2676 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 467s 2s/step - loss: 1.7575 - accuracy: 0.2723 - precision_2: 0.2500 - recall_2: 1.2902e-04 - val_loss: 1.7204 - val_accuracy: 0.2989 - val_precision_2: 0.2222 - val_recall_2: 0.0012
# Epoch 10/10
# 243/243 [==============================] - 460s 2s/step - loss: 1.7345 - accuracy: 0.2864 - precision_2: 0.4653 - recall_2: 0.0030 - val_loss: 1.7198 - val_accuracy: 0.2954 - val_precision_2: 0.5231 - val_recall_2: 0.0197
# 27/27 [==============================] - 17s 489ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.36%
# Average Validation Precision: 32.03%
# Average Validation Recall: 11.04%
# Average Validation F1-score: 16.42%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.49%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.28%
# Average Validation Precision: 25.07%
# Average Validation Recall: 7.32%
# Average Validation F1-score: 10.74%
#
# Metrics for Happy:
# Average Validation Accuracy: 57.92%
# Average Validation Precision: 36.01%
# Average Validation Recall: 68.82%
# Average Validation F1-score: 44.75%
#
# Metrics for Sad:
# Average Validation Accuracy: 81.34%
# Average Validation Precision: 28.35%
# Average Validation Recall: 5.04%
# Average Validation F1-score: 8.51%
#
# Metrics for Surprise:
# Average Validation Accuracy: 73.85%
# Average Validation Precision: 27.29%
# Average Validation Recall: 24.48%
# Average Validation F1-score: 22.17%
#
# Metrics for Neutral:
# Average Validation Accuracy: 83.08%
# Average Validation Precision: 38.90%
# Average Validation Recall: 56.92%
# Average Validation F1-score: 43.26%
#
# Fold 3/10
# Found 15502 validated image filenames belonging to 7 classes.
# Found 1723 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 557s 2s/step - loss: 1.8352 - accuracy: 0.2449 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8173 - val_accuracy: 0.2513 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 484s 2s/step - loss: 1.8227 - accuracy: 0.2502 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8135 - val_accuracy: 0.2513 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 452s 2s/step - loss: 1.8170 - accuracy: 0.2501 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8099 - val_accuracy: 0.2513 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 418s 2s/step - loss: 1.8089 - accuracy: 0.2509 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7973 - val_accuracy: 0.2513 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 440s 2s/step - loss: 1.7955 - accuracy: 0.2525 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7808 - val_accuracy: 0.2589 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 451s 2s/step - loss: 1.7911 - accuracy: 0.2526 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7795 - val_accuracy: 0.2594 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 442s 2s/step - loss: 1.7853 - accuracy: 0.2562 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7575 - val_accuracy: 0.2647 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 445s 2s/step - loss: 1.7717 - accuracy: 0.2629 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7308 - val_accuracy: 0.2757 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 458s 2s/step - loss: 1.7417 - accuracy: 0.2835 - precision_3: 0.5932 - recall_3: 0.0023 - val_loss: 1.7149 - val_accuracy: 0.3111 - val_precision_3: 0.4000 - val_recall_3: 0.0046
# Epoch 10/10
# 243/243 [==============================] - 461s 2s/step - loss: 1.7125 - accuracy: 0.3050 - precision_3: 0.5644 - recall_3: 0.0164 - val_loss: 1.6508 - val_accuracy: 0.3523 - val_precision_3: 0.6296 - val_recall_3: 0.0296
# 27/27 [==============================] - 19s 469ms/step
# Metrics for Angry:
# Average Validation Accuracy: 80.60%
# Average Validation Precision: 28.64%
# Average Validation Recall: 19.44%
# Average Validation F1-score: 20.04%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.49%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 82.12%
# Average Validation Precision: 22.48%
# Average Validation Recall: 8.54%
# Average Validation F1-score: 11.64%
#
# Metrics for Happy:
# Average Validation Accuracy: 64.09%
# Average Validation Precision: 41.60%
# Average Validation Recall: 65.59%
# Average Validation F1-score: 48.42%
#
# Metrics for Sad:
# Average Validation Accuracy: 81.33%
# Average Validation Precision: 32.06%
# Average Validation Recall: 8.40%
# Average Validation F1-score: 12.95%
#
# Metrics for Surprise:
# Average Validation Accuracy: 75.16%
# Average Validation Precision: 27.99%
# Average Validation Recall: 24.05%
# Average Validation F1-score: 23.42%
#
# Metrics for Neutral:
# Average Validation Accuracy: 83.25%
# Average Validation Precision: 38.12%
# Average Validation Recall: 59.76%
# Average Validation F1-score: 44.48%
#
# Fold 4/10
# Found 15502 validated image filenames belonging to 7 classes.
# Found 1723 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 502s 2s/step - loss: 1.8308 - accuracy: 0.2465 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8172 - val_accuracy: 0.2513 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 462s 2s/step - loss: 1.8218 - accuracy: 0.2509 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8171 - val_accuracy: 0.2513 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 449s 2s/step - loss: 1.8181 - accuracy: 0.2502 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8123 - val_accuracy: 0.2513 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 430s 2s/step - loss: 1.8093 - accuracy: 0.2501 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7974 - val_accuracy: 0.2513 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 420s 2s/step - loss: 1.7952 - accuracy: 0.2507 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7893 - val_accuracy: 0.2496 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 460s 2s/step - loss: 1.7915 - accuracy: 0.2524 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7847 - val_accuracy: 0.2525 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 453s 2s/step - loss: 1.7835 - accuracy: 0.2551 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7739 - val_accuracy: 0.2577 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 456s 2s/step - loss: 1.7714 - accuracy: 0.2598 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7487 - val_accuracy: 0.2763 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 460s 2s/step - loss: 1.7433 - accuracy: 0.2822 - precision_4: 0.3750 - recall_4: 5.8057e-04 - val_loss: 1.7098 - val_accuracy: 0.3035 - val_precision_4: 0.6346 - val_recall_4: 0.0192
# Epoch 10/10
# 243/243 [==============================] - 435s 2s/step - loss: 1.7166 - accuracy: 0.3021 - precision_4: 0.5412 - recall_4: 0.0089 - val_loss: 1.6739 - val_accuracy: 0.3355 - val_precision_4: 0.5909 - val_recall_4: 0.0302
# 27/27 [==============================] - 16s 443ms/step
# Metrics for Angry:
# Average Validation Accuracy: 81.79%
# Average Validation Precision: 30.41%
# Average Validation Recall: 16.15%
# Average Validation F1-score: 17.69%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 82.54%
# Average Validation Precision: 22.60%
# Average Validation Recall: 7.83%
# Average Validation F1-score: 11.01%
#
# Metrics for Happy:
# Average Validation Accuracy: 64.31%
# Average Validation Precision: 40.98%
# Average Validation Recall: 66.92%
# Average Validation F1-score: 48.92%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.67%
# Average Validation Precision: 30.16%
# Average Validation Recall: 11.83%
# Average Validation F1-score: 15.52%
#
# Metrics for Surprise:
# Average Validation Accuracy: 76.16%
# Average Validation Precision: 28.02%
# Average Validation Recall: 21.93%
# Average Validation F1-score: 22.58%
#
# Metrics for Neutral:
# Average Validation Accuracy: 82.60%
# Average Validation Precision: 36.68%
# Average Validation Recall: 62.06%
# Average Validation F1-score: 44.37%
#
# Fold 5/10
# Found 15502 validated image filenames belonging to 7 classes.
# Found 1723 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 491s 2s/step - loss: 1.8349 - accuracy: 0.2453 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8153 - val_accuracy: 0.2513 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 448s 2s/step - loss: 1.8232 - accuracy: 0.2485 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8199 - val_accuracy: 0.2513 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 445s 2s/step - loss: 1.8161 - accuracy: 0.2507 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8100 - val_accuracy: 0.2513 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 454s 2s/step - loss: 1.8072 - accuracy: 0.2522 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7967 - val_accuracy: 0.2548 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 463s 2s/step - loss: 1.7949 - accuracy: 0.2531 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7815 - val_accuracy: 0.2589 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 457s 2s/step - loss: 1.7888 - accuracy: 0.2499 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7746 - val_accuracy: 0.2594 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 433s 2s/step - loss: 1.7792 - accuracy: 0.2530 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7639 - val_accuracy: 0.2768 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 459s 2s/step - loss: 1.7608 - accuracy: 0.2664 - precision_5: 0.5000 - recall_5: 6.4508e-05 - val_loss: 1.7330 - val_accuracy: 0.3018 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 473s 2s/step - loss: 1.7348 - accuracy: 0.2895 - precision_5: 0.5362 - recall_5: 0.0024 - val_loss: 1.7131 - val_accuracy: 0.2995 - val_precision_5: 0.6316 - val_recall_5: 0.0070
# Epoch 10/10
# 243/243 [==============================] - 469s 2s/step - loss: 1.7098 - accuracy: 0.3069 - precision_5: 0.5279 - recall_5: 0.0128 - val_loss: 1.6577 - val_accuracy: 0.3413 - val_precision_5: 0.6579 - val_recall_5: 0.0435
# 27/27 [==============================] - 20s 515ms/step
# Metrics for Angry:
# Average Validation Accuracy: 82.07%
# Average Validation Precision: 30.09%
# Average Validation Recall: 15.75%
# Average Validation F1-score: 17.95%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 82.60%
# Average Validation Precision: 21.62%
# Average Validation Recall: 7.40%
# Average Validation F1-score: 10.54%
#
# Metrics for Happy:
# Average Validation Accuracy: 64.14%
# Average Validation Precision: 40.42%
# Average Validation Recall: 68.18%
# Average Validation F1-score: 49.18%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.48%
# Average Validation Precision: 28.94%
# Average Validation Recall: 11.61%
# Average Validation F1-score: 15.39%
#
# Metrics for Surprise:
# Average Validation Accuracy: 76.58%
# Average Validation Precision: 28.61%
# Average Validation Recall: 22.30%
# Average Validation F1-score: 23.44%
#
# Metrics for Neutral:
# Average Validation Accuracy: 82.76%
# Average Validation Precision: 36.52%
# Average Validation Recall: 62.49%
# Average Validation F1-score: 44.70%
#
# Fold 6/10
# Found 15503 validated image filenames belonging to 7 classes.
# Found 1722 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 493s 2s/step - loss: 1.8352 - accuracy: 0.2440 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8161 - val_accuracy: 0.2515 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 450s 2s/step - loss: 1.8219 - accuracy: 0.2503 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8157 - val_accuracy: 0.2515 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 451s 2s/step - loss: 1.8182 - accuracy: 0.2512 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8101 - val_accuracy: 0.2515 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 453s 2s/step - loss: 1.8117 - accuracy: 0.2512 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8147 - val_accuracy: 0.2515 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 442s 2s/step - loss: 1.7987 - accuracy: 0.2526 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7827 - val_accuracy: 0.2642 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 438s 2s/step - loss: 1.7918 - accuracy: 0.2529 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7794 - val_accuracy: 0.2567 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 453s 2s/step - loss: 1.7866 - accuracy: 0.2538 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7630 - val_accuracy: 0.2625 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 450s 2s/step - loss: 1.7716 - accuracy: 0.2619 - precision_6: 1.0000 - recall_6: 6.4504e-05 - val_loss: 1.7402 - val_accuracy: 0.2915 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 414s 2s/step - loss: 1.7443 - accuracy: 0.2788 - precision_6: 0.4118 - recall_6: 9.0305e-04 - val_loss: 1.7118 - val_accuracy: 0.3049 - val_precision_6: 0.6000 - val_recall_6: 0.0157
# Epoch 10/10
# 243/243 [==============================] - 456s 2s/step - loss: 1.7173 - accuracy: 0.3019 - precision_6: 0.5640 - recall_6: 0.0105 - val_loss: 1.6446 - val_accuracy: 0.3548 - val_precision_6: 0.6818 - val_recall_6: 0.0174
# 27/27 [==============================] - 16s 459ms/step
# Metrics for Angry:
# Average Validation Accuracy: 82.41%
# Average Validation Precision: 29.74%
# Average Validation Recall: 14.58%
# Average Validation F1-score: 17.18%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 82.92%
# Average Validation Precision: 22.19%
# Average Validation Recall: 6.92%
# Average Validation F1-score: 10.05%
#
# Metrics for Happy:
# Average Validation Accuracy: 64.51%
# Average Validation Precision: 40.43%
# Average Validation Recall: 68.78%
# Average Validation F1-score: 49.60%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.95%
# Average Validation Precision: 30.44%
# Average Validation Recall: 10.29%
# Average Validation F1-score: 13.95%
#
# Metrics for Surprise:
# Average Validation Accuracy: 75.16%
# Average Validation Precision: 28.18%
# Average Validation Recall: 26.69%
# Average Validation F1-score: 25.18%
#
# Metrics for Neutral:
# Average Validation Accuracy: 83.50%
# Average Validation Precision: 37.78%
# Average Validation Recall: 62.25%
# Average Validation F1-score: 45.79%
#
# Fold 7/10
# Found 15503 validated image filenames belonging to 7 classes.
# Found 1722 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 486s 2s/step - loss: 1.8344 - accuracy: 0.2405 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8147 - val_accuracy: 0.2515 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 463s 2s/step - loss: 1.8225 - accuracy: 0.2499 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8130 - val_accuracy: 0.2515 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 459s 2s/step - loss: 1.8167 - accuracy: 0.2510 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8086 - val_accuracy: 0.2515 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 433s 2s/step - loss: 1.8118 - accuracy: 0.2514 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7984 - val_accuracy: 0.2515 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 445s 2s/step - loss: 1.7945 - accuracy: 0.2518 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7910 - val_accuracy: 0.2573 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 454s 2s/step - loss: 1.7893 - accuracy: 0.2531 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7842 - val_accuracy: 0.2509 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 413s 2s/step - loss: 1.7838 - accuracy: 0.2527 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7808 - val_accuracy: 0.2526 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 449s 2s/step - loss: 1.7728 - accuracy: 0.2599 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7520 - val_accuracy: 0.2816 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 461s 2s/step - loss: 1.7452 - accuracy: 0.2759 - precision_7: 0.3810 - recall_7: 5.1603e-04 - val_loss: 1.7115 - val_accuracy: 0.2950 - val_precision_7: 0.4286 - val_recall_7: 0.0052
# Epoch 10/10
# 243/243 [==============================] - 443s 2s/step - loss: 1.7192 - accuracy: 0.2947 - precision_7: 0.5704 - recall_7: 0.0102 - val_loss: 1.7012 - val_accuracy: 0.3113 - val_precision_7: 0.5000 - val_recall_7: 0.0070
# 27/27 [==============================] - 17s 446ms/step
# Metrics for Angry:
# Average Validation Accuracy: 82.58%
# Average Validation Precision: 29.14%
# Average Validation Recall: 13.87%
# Average Validation F1-score: 16.72%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 82.94%
# Average Validation Precision: 21.76%
# Average Validation Recall: 6.74%
# Average Validation F1-score: 9.87%
#
# Metrics for Happy:
# Average Validation Accuracy: 65.85%
# Average Validation Precision: 41.47%
# Average Validation Recall: 64.57%
# Average Validation F1-score: 48.67%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.67%
# Average Validation Precision: 29.81%
# Average Validation Recall: 10.93%
# Average Validation F1-score: 14.65%
#
# Metrics for Surprise:
# Average Validation Accuracy: 72.43%
# Average Validation Precision: 27.50%
# Average Validation Recall: 33.02%
# Average Validation F1-score: 26.63%
#
# Metrics for Neutral:
# Average Validation Accuracy: 84.29%
# Average Validation Precision: 39.62%
# Average Validation Recall: 59.30%
# Average Validation F1-score: 45.77%
#
# Fold 8/10
# Found 15503 validated image filenames belonging to 7 classes.
# Found 1722 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 489s 2s/step - loss: 1.8339 - accuracy: 0.2456 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8156 - val_accuracy: 0.2515 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 420s 2s/step - loss: 1.8201 - accuracy: 0.2509 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8149 - val_accuracy: 0.2515 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 352s 1s/step - loss: 1.8167 - accuracy: 0.2503 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8089 - val_accuracy: 0.2515 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 349s 1s/step - loss: 1.8034 - accuracy: 0.2523 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7945 - val_accuracy: 0.2544 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 333s 1s/step - loss: 1.7939 - accuracy: 0.2529 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7883 - val_accuracy: 0.2607 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 348s 1s/step - loss: 1.7897 - accuracy: 0.2526 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7855 - val_accuracy: 0.2584 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 356s 1s/step - loss: 1.7849 - accuracy: 0.2535 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7677 - val_accuracy: 0.2573 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 356s 1s/step - loss: 1.7751 - accuracy: 0.2596 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7592 - val_accuracy: 0.2764 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 376s 2s/step - loss: 1.7554 - accuracy: 0.2758 - precision_8: 0.5000 - recall_8: 6.4504e-05 - val_loss: 1.7121 - val_accuracy: 0.3078 - val_precision_8: 1.0000 - val_recall_8: 5.8072e-04
# Epoch 10/10
# 243/243 [==============================] - 348s 1s/step - loss: 1.7271 - accuracy: 0.2909 - precision_8: 0.4929 - recall_8: 0.0045 - val_loss: 1.6577 - val_accuracy: 0.3432 - val_precision_8: 0.6531 - val_recall_8: 0.0186
# 27/27 [==============================] - 15s 420ms/step
# Metrics for Angry:
# Average Validation Accuracy: 82.98%
# Average Validation Precision: 29.88%
# Average Validation Recall: 12.51%
# Average Validation F1-score: 15.31%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 82.95%
# Average Validation Precision: 20.62%
# Average Validation Recall: 6.31%
# Average Validation F1-score: 9.28%
#
# Metrics for Happy:
# Average Validation Accuracy: 66.48%
# Average Validation Precision: 41.84%
# Average Validation Recall: 64.38%
# Average Validation F1-score: 49.10%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.57%
# Average Validation Precision: 29.61%
# Average Validation Recall: 11.33%
# Average Validation F1-score: 15.16%
#
# Metrics for Surprise:
# Average Validation Accuracy: 72.08%
# Average Validation Precision: 27.45%
# Average Validation Recall: 34.84%
# Average Validation F1-score: 27.61%
#
# Metrics for Neutral:
# Average Validation Accuracy: 84.01%
# Average Validation Precision: 38.88%
# Average Validation Recall: 59.98%
# Average Validation F1-score: 45.59%
#
# Fold 9/10
# Found 15503 validated image filenames belonging to 7 classes.
# Found 1722 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 387s 1s/step - loss: 1.8357 - accuracy: 0.2449 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8162 - val_accuracy: 0.2515 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 358s 1s/step - loss: 1.8199 - accuracy: 0.2491 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8135 - val_accuracy: 0.2515 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 358s 1s/step - loss: 1.8174 - accuracy: 0.2507 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8093 - val_accuracy: 0.2515 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 247s 1s/step - loss: 1.8099 - accuracy: 0.2507 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7988 - val_accuracy: 0.2515 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 259s 1s/step - loss: 1.7974 - accuracy: 0.2519 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7799 - val_accuracy: 0.2596 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 241s 988ms/step - loss: 1.7916 - accuracy: 0.2529 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7807 - val_accuracy: 0.2666 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 264s 1s/step - loss: 1.7850 - accuracy: 0.2523 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7637 - val_accuracy: 0.2689 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 242s 995ms/step - loss: 1.7745 - accuracy: 0.2554 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7581 - val_accuracy: 0.2991 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 229s 939ms/step - loss: 1.7472 - accuracy: 0.2826 - precision_9: 0.4286 - recall_9: 3.8702e-04 - val_loss: 1.6959 - val_accuracy: 0.3211 - val_precision_9: 0.4000 - val_recall_9: 0.0012
# Epoch 10/10
# 243/243 [==============================] - 235s 962ms/step - loss: 1.7097 - accuracy: 0.3085 - precision_9: 0.5578 - recall_9: 0.0159 - val_loss: 1.6550 - val_accuracy: 0.3328 - val_precision_9: 0.5890 - val_recall_9: 0.0499
# 27/27 [==============================] - 9s 261ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.09%
# Average Validation Precision: 28.37%
# Average Validation Recall: 11.54%
# Average Validation F1-score: 14.29%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.15%
# Average Validation Precision: 20.18%
# Average Validation Recall: 5.79%
# Average Validation F1-score: 8.58%
#
# Metrics for Happy:
# Average Validation Accuracy: 67.21%
# Average Validation Precision: 42.43%
# Average Validation Recall: 63.92%
# Average Validation F1-score: 49.53%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.38%
# Average Validation Precision: 29.01%
# Average Validation Recall: 11.52%
# Average Validation F1-score: 15.37%
#
# Metrics for Surprise:
# Average Validation Accuracy: 71.98%
# Average Validation Precision: 27.27%
# Average Validation Recall: 35.19%
# Average Validation F1-score: 27.96%
#
# Metrics for Neutral:
# Average Validation Accuracy: 83.26%
# Average Validation Precision: 37.87%
# Average Validation Recall: 62.08%
# Average Validation F1-score: 45.33%
#
# Fold 10/10
# Found 15503 validated image filenames belonging to 7 classes.
# Found 1722 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 271s 1s/step - loss: 1.8358 - accuracy: 0.2476 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8159 - val_accuracy: 0.2509 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 259s 1s/step - loss: 1.8215 - accuracy: 0.2494 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8121 - val_accuracy: 0.2509 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 222s 912ms/step - loss: 1.8164 - accuracy: 0.2503 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8097 - val_accuracy: 0.2509 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 264s 1s/step - loss: 1.8137 - accuracy: 0.2512 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8046 - val_accuracy: 0.2509 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 247s 1s/step - loss: 1.8004 - accuracy: 0.2505 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7828 - val_accuracy: 0.2520 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 253s 1s/step - loss: 1.7921 - accuracy: 0.2529 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8134 - val_accuracy: 0.2398 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 249s 1s/step - loss: 1.7856 - accuracy: 0.2545 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7775 - val_accuracy: 0.2480 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 245s 1s/step - loss: 1.7792 - accuracy: 0.2538 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7596 - val_accuracy: 0.2631 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 207s 850ms/step - loss: 1.7603 - accuracy: 0.2712 - precision_10: 1.0000 - recall_10: 6.4504e-05 - val_loss: 1.7109 - val_accuracy: 0.3107 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 10/10
# 243/243 [==============================] - 258s 1s/step - loss: 1.7288 - accuracy: 0.2917 - precision_10: 0.5263 - recall_10: 0.0045 - val_loss: 1.6753 - val_accuracy: 0.3368 - val_precision_10: 0.5795 - val_recall_10: 0.0296
# 27/27 [==============================] - 7s 221ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.32%
# Average Validation Precision: 29.60%
# Average Validation Recall: 11.38%
# Average Validation F1-score: 14.46%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.25%
# Average Validation Precision: 19.48%
# Average Validation Recall: 5.41%
# Average Validation F1-score: 8.07%
#
# Metrics for Happy:
# Average Validation Accuracy: 66.54%
# Average Validation Precision: 41.79%
# Average Validation Recall: 64.94%
# Average Validation F1-score: 49.42%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.51%
# Average Validation Precision: 28.86%
# Average Validation Recall: 11.11%
# Average Validation F1-score: 14.99%
#
# Metrics for Surprise:
# Average Validation Accuracy: 72.77%
# Average Validation Precision: 27.89%
# Average Validation Recall: 33.63%
# Average Validation F1-score: 27.64%
#
# Metrics for Neutral:
# Average Validation Accuracy: 82.76%
# Average Validation Precision: 37.21%
# Average Validation Recall: 63.88%
# Average Validation F1-score: 45.29%
#
# Overall Average Metrics:
# Average Validation Accuracy: 80.95%
# Average Validation Precision: 26.40%
# Average Validation Recall: 27.19%
# Average Validation F1-score: 22.84%
# Confusion Matrix:
# [[ 273    0  117  784  175  661  387]
#  [  10    0   15   89   37   75   36]
#  [ 161    0  133  774  158  516  716]
#  [ 175    0   82 2811  213  580  468]
#  [ 131    0  132 1288  331  780  317]
#  [ 213    0  135  975  242  975  358]
#  [  59    0   80  336   57  155 1215]]
